# %% [markdown]
# # This notebook is only for colab usage !!!

# %%
import os 
from google.colab import output
#os.chdir("drive/MyDrive/NLP_A3")

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install transformers seqeval[gpu]
output.clear()

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizerFast, BertConfig, BertForTokenClassification
from tqdm import tqdm

# %%
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %% [markdown]
# ## Converting tokenization files into a more suitable format

# %%
dataframe = pd.read_csv("/content/gdrive/MyDrive/ner.csv")
dataframe.head
# Out:
# <bound method NDFrame.head of             Sentence #                                           Sentence  \
# 0          Sentence: 1  Thousands of demonstrators have marched throug...
# 1          Sentence: 2  Families of soldiers killed in the conflict jo...
# 2          Sentence: 3  They marched from the Houses of Parliament to ...
# 3          Sentence: 4  Police put the number of marchers at 10,000 wh...
# 4          Sentence: 5  The protest comes on the eve of the annual con...
# ...                ...                                                ...
# 47954  Sentence: 47955  Indian border security forces are accusing the...
# 47955  Sentence: 47956  Indian officials said no one was injured in Sa...
# 47956  Sentence: 47957  Two more landed in fields belonging to a nearb...
# 47957  Sentence: 47958  They say not all of the rockets exploded upon ...
# 47958  Sentence: 47959    Indian forces said they responded to the attack
#
#                                                      POS  \
# 0      ['NNS', 'IN', 'NNS', 'VBP', 'VBN', 'IN', 'NNP'...
# 1      ['NNS', 'IN', 'NNS', 'VBN', 'IN', 'DT', 'NN', ...
# 2      ['PRP', 'VBD', 'IN', 'DT', 'NNS', 'IN', 'NN', ...
# 3      ['NNS', 'VBD', 'DT', 'NN', 'IN', 'NNS', 'IN', ...
# 4      ['DT', 'NN', 'VBZ', 'IN', 'DT', 'NN', 'IN', 'D...
# ...                                                  ...
# 47954  ['JJ', 'NN', 'NN', 'NNS', 'VBP', 'VBG', 'PRP$'...
# 47955  ['JJ', 'NNS', 'VBD', 'DT', 'NN', 'VBD', 'VBN',...
# 47956  ['CD', 'JJR', 'VBD', 'IN', 'NNS', 'VBG', 'TO',...
# 47957  ['PRP', 'VBP', 'RB', 'DT', 'IN', 'DT', 'NNS', ...
# 47958  ['JJ', 'NNS', 'VBD', 'PRP', 'VBD', 'TO', 'DT',...
#
#                                                      Tag
# 0      ['O', 'O', 'O', 'O', 'O', 'O', 'B-geo', 'O', '...
# 1      ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2      ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3      ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4      ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# ...                                                  ...
# 47954  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'B-gpe...
# 47955  ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '...
# 47956  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 47957  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 47958       ['B-gpe', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# [47959 rows x 4 columns]>

# %% [markdown]
# ## Unique labels

# %%
from collections import Counter


unique_labels = set()
label_counter = Counter()
for list_of_tags in dataframe["Tag"]:
  for tag in eval(list_of_tags):
    unique_labels.add(tag)
    label_counter[tag] += 1

# %%
from pprint import pprint
pprint(label_counter)
# Out:
# Counter({'O': 887908,
#          'B-geo': 37644,
#          'B-tim': 20333,
#          'B-org': 20143,
#          'I-per': 17251,
#          'B-per': 16990,
#          'I-org': 16784,
#          'B-gpe': 15870,
#          'I-geo': 7414,
#          'I-tim': 6528,
#          'B-art': 402,
#          'B-eve': 308,
#          'I-art': 297,
#          'I-eve': 253,
#          'B-nat': 201,
#          'I-gpe': 198,
#          'I-nat': 51})

# %%
# Map each label into its id representation and vice versa  
# https://towardsdatascience.com/named-entity-recognition-with-bert-in-pytorch-a454405e0b6a
labels_to_ids = {k: v for v, k in enumerate(sorted(unique_labels))}
ids_to_labels = {v: k for v, k in enumerate(sorted(unique_labels))}
print(labels_to_ids)
# Out:
# {'B-art': 0, 'B-eve': 1, 'B-geo': 2, 'B-gpe': 3, 'B-nat': 4, 'B-org': 5, 'B-per': 6, 'B-tim': 7, 'I-art': 8, 'I-eve': 9, 'I-geo': 10, 'I-gpe': 11, 'I-nat': 12, 'I-org': 13, 'I-per': 14, 'I-tim': 15, 'O': 16}

# %% [markdown]
# ## Transforming word tokens into tokens for BERT

# %%
import transformers
from transformers import BertTokenizerFast

tokenizer = BertTokenizerFast.from_pretrained('dslim/bert-base-NER')

def ids_to_tokens(input): 
    return tokenizer.convert_ids_to_tokens(input)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]

# %%
def align_label(texts, labels):
    tokenized_inputs = tokenizer(texts, padding='max_length', max_length=512, truncation=True)

    word_ids = tokenized_inputs.word_ids()
    previous_word_idx = None
    label_ids = []
    for word_idx in word_ids:
        if word_idx is None:
            label_ids.append(-100)
        elif word_idx != previous_word_idx:
            try:
                label_ids.append(labels_to_ids[labels[word_idx]])
            except:
                label_ids.append(-100)
        else:
            try:
                label_ids.append(labels_to_ids[labels[word_idx]] if True else -100)
            except:
                label_ids.append(-100)
        previous_word_idx = word_idx

    return label_ids

# %%
align_label(df_train["Sentence"].iloc[0], eval(df_train["Tag"].iloc[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4cac222ed8c6> in <cell line: 1>()
# ----> 1 align_label(df_train["Sentence"].iloc[0], eval(df_train["Tag"].iloc[0]))
#
# NameError: name 'df_train' is not defined

# %% [markdown]
# BERT Aligned tokens are done.

# %% [markdown]
# ## Model Training

# %% [markdown]
# https://towardsdatascience.com/named-entity-recognition-with-bert-in-pytorch-a454405e0b6a

# %%
import torch

class DataSequence(torch.utils.data.Dataset):
    def __init__(self, df):
        lb = map(eval, df['Tag'])
        txt = df['Sentence'].values.tolist()
        self.texts = [tokenizer(str(i),
                               padding='max_length', max_length = 512, truncation=True, return_tensors="pt") for i in txt]
        self.labels = [align_label(i,j) for i,j in zip(txt, lb)]

    def __len__(self):
        return len(self.labels)

    def get_batch_data(self, idx):
        return self.texts[idx]

    def get_batch_labels(self, idx):
        return torch.LongTensor(self.labels[idx])

    def __getitem__(self, idx):
        batch_data = self.get_batch_data(idx)
        batch_labels = self.get_batch_labels(idx)

        return batch_data, batch_labels

# %%
import numpy as np

df_train, df_val, df_test = np.split(dataframe[:].sample(frac=1, random_state=42),
                            [int(.8 * len(dataframe[:])), int(.9 * len(dataframe[:]))])

# %%
df_test.shape
# Out:
# (4796, 4)

# %%
from transformers import BertForTokenClassification

class BertModel(torch.nn.Module): 
    def __init__(self): 
        super(BertModel, self).__init__() 
        self.bert = BertForTokenClassification.from_pretrained('dslim/bert-base-NER', num_labels=len(unique_labels), ignore_mismatched_sizes=True)

    def forward(self,input_ids, label=None): 
        output = self.bert(labels=label, input_ids = input_ids, return_dict=False) 
        return output

# %%
train_dataset = DataSequence(df_train)
type(train_dataset.lb)

# %%
from torch.optim import SGD

def train_loop(model, df_train, df_val): 
    train_dataset = DataSequence(df_train)
    val_dataset = DataSequence(df_val)

    train_dataloader = DataLoader(train_dataset, num_workers=4, batch_size=BATCH_SIZE, shuffle=True)
    val_dataloader = DataLoader(val_dataset, num_workers=4, batch_size=BATCH_SIZE)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")
    #device = "cpu"

    optimizer = SGD(model.parameters(), lr=LEARNING_RATE)

    if use_cuda:
        model = model.cuda()

    best_acc = 0
    best_loss = 1000
    print("All is ok")
    for epoch_num in range(EPOCHS): 
        total_acc_train = 0
        total_loss_train = 0

        model.train()

        for train_data, train_label in tqdm(train_dataloader): 
            #print(train_label)
            train_label = train_label.to(device)
            #mask = train_data['attention_mask'].squeeze(1).to(device)
            input_id = train_data['input_ids'].squeeze(1).to(device)
            
            optimizer.zero_grad()
            loss, logits = model(input_id, train_label)
          
            for i in range(logits.shape[0]): 
                #words = sentence.replace("-", "").split()
                #print(logits_clean)
                #for i in range(len(eval(answer))-1):
                #    print(words[i], eval(answer)[i])
                tokenized_sentence = ids_to_tokens(train_data["input_ids"][0][0])
                #print(tokenized_sentence)
                
                logits_clean = logits[i][train_label[i] != -100]
                label_clean = train_label[i][train_label[i] != -100]
                predictions = logits_clean.argmax(dim=1)
                #print(predictions)
                #print(label_clean)
                #print([ids_to_labels[x] for x in label_clean.cpu().numpy()])
                #print([ids_to_labels[x] for x in label_clean])

                acc = (predictions == label_clean).float().mean()
                total_acc_train += acc
                total_loss_train += loss.item()

            loss.backward()
            optimizer.step()

        model.eval()

        total_acc_val = 0
        total_loss_val = 0

        for val_data, val_label in val_dataloader: 
            val_label = val_label.to(device)
            #mask = val_data['attention_mask'].squeeze(1).to(device)
            input_id = val_data['input_ids'].squeeze(1).to(device)

            loss, logits = model(input_id, val_label)

            for i in range(logits.shape[0]): 
              logits_clean = logits[i][val_label[i] != -100]
              label_clean = val_label[i][val_label[i] != -100]

              predictions = logits_clean.argmax(dim=1)
              acc = (predictions == label_clean).float().mean()
              total_acc_val += acc
              total_loss_val += loss.item()

        val_accuracy = total_acc_val / len(df_val)
        val_loss = total_loss_val / len(df_val)
        print(
            f'Epochs: {epoch_num + 1} | Loss: {total_loss_train / len(df_train): .3f} | Accuracy: {total_acc_train / len(df_train): .3f} | Val_Loss: {total_loss_val / len(df_val): .3f} | Accuracy: {total_acc_val / len(df_val): .3f}')

LEARNING_RATE = 0.001
EPOCHS = 2
BATCH_SIZE = 2

model = BertModel()
try:
  train_loop(model, df_train, df_val)
except:
  pass
finally:
  torch.save(model.state_dict(), "/content/gdrive/MyDrive/NLP_A3/bert_trainedNEREnglish")
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at dslim/bert-base-NER and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([9, 768]) in the checkpoint and torch.Size([17, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([9]) in the checkpoint and torch.Size([17]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# All is ok
# 100%|██████████| 19184/19184 [1:06:03<00:00,  4.84it/s]
# Epochs: 1 | Loss:  0.345 | Accuracy:  0.905 | Val_Loss:  0.246 | Accuracy:  0.928
# 100%|██████████| 19184/19184 [1:05:59<00:00,  4.85it/s]
# Epochs: 2 | Loss:  0.228 | Accuracy:  0.933 | Val_Loss:  0.207 | Accuracy:  0.937

# %%
from transformers import pipeline 
model = BertModel()

model.load_state_dict(torch.load('/content/gdrive/MyDrive/NLP_A3/bert_trainedNEREnglish', map_location=torch.device('cpu')))
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at dslim/bert-base-NER and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([9, 768]) in the checkpoint and torch.Size([17, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([9]) in the checkpoint and torch.Size([17]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <All keys matched successfully>

# %%
test_dataset = DataSequence(df_test)
test_dataloader = DataLoader(test_dataset, num_workers=4, batch_size=1)
total_acc_test = 0
total_loss_test = 0
i = 0
for test_data, test_label in test_dataloader: 
    test_label = test_label.to(device)
    #mask = val_data['attention_mask'].squeeze(1).to(device)
    input_id = test_data['input_ids'].squeeze(1).to(device)

    loss, logits = model(input_id, test_label)

    for i in range(logits.shape[0]): 
      logits_clean = logits[i][test_label[i] != -100]
      label_clean = test_label[i][test_label[i] != -100]

      predictions = logits_clean.argmax(dim=1)
      acc = (predictions == label_clean).float().mean()
      total_acc_test += acc
      total_loss_test += loss.item()

    test_accuracy = total_acc_test / len(df_test)
    test_loss = total_loss_test / len(df_test)

print(f'Test_Loss: {total_loss_test / len(df_test): .3f} | Accuracy: {total_acc_test / len(df_test): .3f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 0
# Test_Loss:  0.093 | Accuracy:  0.449
# 0
# Test_Loss:  0.093 | Accuracy:  0.449
# 0
# Test_Loss:  0.094 | Accuracy:  0.450
# 0
# Test_Loss:  0.094 | Accuracy:  0.450
# 0
# Test_Loss:  0.094 | Accuracy:  0.450
# 0
# Test_Loss:  0.094 | Accuracy:  0.450
# 0
# Test_Loss:  0.094 | Accuracy:  0.450
# 0
# Test_Loss:  0.094 | Accuracy:  0.450
# 0
# Test_Loss:  0.094 | Accuracy:  0.451
# 0
# Test_Loss:  0.094 | Accuracy:  0.451
# 0
# Test_Loss:  0.094 | Accuracy:  0.451
# 0
# Test_Loss:  0.094 | Accuracy:  0.451
# 0
# Test_Loss:  0.094 | Accuracy:  0.451
# 0
# Test_Loss:  0.094 | Accuracy:  0.452
# 0
# Test_Loss:  0.094 | Accuracy:  0.452
# 0
# Test_Loss:  0.094 | Accuracy:  0.452
# 0
# Test_Loss:  0.094 | Accuracy:  0.452
# 0
# Test_Loss:  0.094 | Accuracy:  0.452
# 0
# Test_Loss:  0.094 | Accuracy:  0.453
# 0
# Test_Loss:  0.094 | Accuracy:  0.453
# 0
# Test_Loss:  0.094 | Accuracy:  0.453
# 0
# Test_Loss:  0.094 | Accuracy:  0.453
# 0
# Test_Loss:  0.095 | Accuracy:  0.453
# 0
# Test_Loss:  0.095 | Accuracy:  0.454
# 0
# Test_Loss:  0.095 | Accuracy:  0.454
# 0
# Test_Loss:  0.095 | Accuracy:  0.454
# 0
# Test_Loss:  0.095 | Accuracy:  0.454
# 0
# Test_Loss:  0.095 | Accuracy:  0.454
# 0
# Test_Loss:  0.095 | Accuracy:  0.454
# 0
# Test_Loss:  0.095 | Accuracy:  0.455
# 0
# Test_Loss:  0.095 | Accuracy:  0.455
# 0
# Test_Loss:  0.095 | Accuracy:  0.455
# 0
# Test_Loss:  0.095 | Accuracy:  0.455
# 0
# Test_Loss:  0.095 | Accuracy:  0.455
# 0
# Test_Loss:  0.095 | Accuracy:  0.456
# 0
# Test_Loss:  0.095 | Accuracy:  0.456
# 0
# Test_Loss:  0.095 | Accuracy:  0.456
# 0
# Test_Loss:  0.095 | Accuracy:  0.456
# 0
# Test_Loss:  0.095 | Accuracy:  0.456
# 0
# Test_Loss:  0.095 | Accuracy:  0.457
# 0
# Test_Loss:  0.095 | Accuracy:  0.457
# 0
# Test_Loss:  0.095 | Accuracy:  0.457
# 0
# Test_Loss:  0.095 | Accuracy:  0.457
# 0
# Test_Loss:  0.095 | Accuracy:  0.458
# 0
# Test_Loss:  0.095 | Accuracy:  0.458
# 0
# Test_Loss:  0.095 | Accuracy:  0.458
# 0
# Test_Loss:  0.095 | Accuracy:  0.458
# 0
# Test_Loss:  0.095 | Accuracy:  0.458
# 0
# Test_Loss:  0.095 | Accuracy:  0.459
# 0
# Test_Loss:  0.095 | Accuracy:  0.459
# 0
# Test_Loss:  0.095 | Accuracy:  0.459
# 0
# Test_Loss:  0.095 | Accuracy:  0.459
# 0
# Test_Loss:  0.095 | Accuracy:  0.459
# 0
# Test_Loss:  0.095 | Accuracy:  0.460
# 0
# Test_Loss:  0.095 | Accuracy:  0.460
# 0
# Test_Loss:  0.096 | Accuracy:  0.460
# 0
# Test_Loss:  0.096 | Accuracy:  0.460
# 0
# Test_Loss:  0.096 | Accuracy:  0.460
# 0
# Test_Loss:  0.096 | Accuracy:  0.461
# 0
# Test_Loss:  0.096 | Accuracy:  0.461
# 0
# Test_Loss:  0.096 | Accuracy:  0.461
# 0
# Test_Loss:  0.096 | Accuracy:  0.461
# 0
# Test_Loss:  0.096 | Accuracy:  0.461
# 0
# Test_Loss:  0.096 | Accuracy:  0.461
# 0
# Test_Loss:  0.096 | Accuracy:  0.462
# 0
# Test_Loss:  0.096 | Accuracy:  0.462
# 0
# Test_Loss:  0.096 | Accuracy:  0.462
# 0
# Test_Loss:  0.096 | Accuracy:  0.462
# 0
# Test_Loss:  0.096 | Accuracy:  0.462
# 0
# Test_Loss:  0.096 | Accuracy:  0.463
# 0
# Test_Loss:  0.096 | Accuracy:  0.463
# 0
# Test_Loss:  0.096 | Accuracy:  0.463
# 0
# Test_Loss:  0.096 | Accuracy:  0.463
# 0
# Test_Loss:  0.096 | Accuracy:  0.463
# 0
# Test_Loss:  0.096 | Accuracy:  0.464
# 0
# Test_Loss:  0.096 | Accuracy:  0.464
# 0
# Test_Loss:  0.096 | Accuracy:  0.464
# 0
# Test_Loss:  0.096 | Accuracy:  0.464
# 0
# Test_Loss:  0.096 | Accuracy:  0.464
# 0
# Test_Loss:  0.097 | Accuracy:  0.465
# 0
# Test_Loss:  0.097 | Accuracy:  0.465
# 0
# Test_Loss:  0.097 | Accuracy:  0.465
# 0
# Test_Loss:  0.097 | Accuracy:  0.465
# 0
# Test_Loss:  0.097 | Accuracy:  0.465
# 0
# Test_Loss:  0.097 | Accuracy:  0.466
# 0
# Test_Loss:  0.097 | Accuracy:  0.466
# 0
# Test_Loss:  0.097 | Accuracy:  0.466
# 0
# Test_Loss:  0.097 | Accuracy:  0.466
# 0
# Test_Loss:  0.097 | Accuracy:  0.466
# 0
# Test_Loss:  0.097 | Accuracy:  0.467
# 0
# Test_Loss:  0.097 | Accuracy:  0.467
# 0
# Test_Loss:  0.097 | Accuracy:  0.467
# 0
# Test_Loss:  0.097 | Accuracy:  0.467
# 0
# Test_Loss:  0.097 | Accuracy:  0.467
# 0
# Test_Loss:  0.098 | Accuracy:  0.467
# 0
# Test_Loss:  0.098 | Accuracy:  0.468
# 0
# Test_Loss:  0.098 | Accuracy:  0.468
# 0
# Test_Loss:  0.098 | Accuracy:  0.468
# 0
# Test_Loss:  0.098 | Accuracy:  0.468
# 0
# Test_Loss:  0.098 | Accuracy:  0.468
# 0
# Test_Loss:  0.098 | Accuracy:  0.469
# 0
# Test_Loss:  0.098 | Accuracy:  0.469
# 0
# Test_Loss:  0.098 | Accuracy:  0.469
# 0
# Test_Loss:  0.098 | Accuracy:  0.469
# 0
# Test_Loss:  0.098 | Accuracy:  0.469
# 0
# Test_Loss:  0.098 | Accuracy:  0.470
# 0
# Test_Loss:  0.098 | Accuracy:  0.470
# 0
# Test_Loss:  0.098 | Accuracy:  0.470
# 0
# Test_Loss:  0.098 | Accuracy:  0.470
# 0
# Test_Loss:  0.098 | Accuracy:  0.470
# 0
# Test_Loss:  0.098 | Accuracy:  0.471
# 0
# Test_Loss:  0.098 | Accuracy:  0.471
# 0
# Test_Loss:  0.098 | Accuracy:  0.471
# 0
# Test_Loss:  0.098 | Accuracy:  0.471
# 0
# Test_Loss:  0.098 | Accuracy:  0.471
# 0
# Test_Loss:  0.098 | Accuracy:  0.472
# 0
# Test_Loss:  0.098 | Accuracy:  0.472
# 0
# Test_Loss:  0.098 | Accuracy:  0.472
# 0
# Test_Loss:  0.098 | Accuracy:  0.472
# 0
# Test_Loss:  0.098 | Accuracy:  0.472
# 0
# Test_Loss:  0.099 | Accuracy:  0.473
# 0
# Test_Loss:  0.099 | Accuracy:  0.473
# 0
# Test_Loss:  0.099 | Accuracy:  0.473
# 0
# Test_Loss:  0.099 | Accuracy:  0.473
# 0
# Test_Loss:  0.099 | Accuracy:  0.473
# 0
# Test_Loss:  0.099 | Accuracy:  0.473
# 0
# Test_Loss:  0.099 | Accuracy:  0.474
# 0
# Test_Loss:  0.099 | Accuracy:  0.474
# 0
# Test_Loss:  0.099 | Accuracy:  0.474
# 0
# Test_Loss:  0.099 | Accuracy:  0.474
# 0
# Test_Loss:  0.099 | Accuracy:  0.474
# 0
# Test_Loss:  0.099 | Accuracy:  0.475
# 0
# Test_Loss:  0.099 | Accuracy:  0.475
# 0
# Test_Loss:  0.099 | Accuracy:  0.475
# 0
# Test_Loss:  0.099 | Accuracy:  0.475
# 0
# Test_Loss:  0.099 | Accuracy:  0.475
# 0
# Test_Loss:  0.099 | Accuracy:  0.476
# 0
# Test_Loss:  0.100 | Accuracy:  0.476
# 0
# Test_Loss:  0.100 | Accuracy:  0.476
# 0
# Test_Loss:  0.100 | Accuracy:  0.476
# 0
# Test_Loss:  0.100 | Accuracy:  0.476
# 0
# Test_Loss:  0.100 | Accuracy:  0.476
# 0
# Test_Loss:  0.100 | Accuracy:  0.477
# 0
# Test_Loss:  0.100 | Accuracy:  0.477
# 0
# Test_Loss:  0.100 | Accuracy:  0.477
# 0
# Test_Loss:  0.100 | Accuracy:  0.477
# 0
# Test_Loss:  0.100 | Accuracy:  0.477
# 0
# Test_Loss:  0.100 | Accuracy:  0.478
# 0
# Test_Loss:  0.100 | Accuracy:  0.478
# 0
# Test_Loss:  0.100 | Accuracy:  0.478
# 0
# Test_Loss:  0.100 | Accuracy:  0.478
# 0
# Test_Loss:  0.100 | Accuracy:  0.478
# 0
# Test_Loss:  0.100 | Accuracy:  0.479
# 0
# Test_Loss:  0.100 | Accuracy:  0.479
# 0
# Test_Loss:  0.100 | Accuracy:  0.479
# 0
# Test_Loss:  0.100 | Accuracy:  0.479
# 0
# Test_Loss:  0.100 | Accuracy:  0.479
# 0
# Test_Loss:  0.100 | Accuracy:  0.480
# 0
# Test_Loss:  0.100 | Accuracy:  0.480
# 0
# Test_Loss:  0.100 | Accuracy:  0.480
# 0
# Test_Loss:  0.101 | Accuracy:  0.480
# 0
# Test_Loss:  0.101 | Accuracy:  0.480
# 0
# Test_Loss:  0.101 | Accuracy:  0.481
# 0
# Test_Loss:  0.101 | Accuracy:  0.481
# 0
# Test_Loss:  0.101 | Accuracy:  0.481
# 0
# Test_Loss:  0.101 | Accuracy:  0.481
# 0
# Test_Loss:  0.101 | Accuracy:  0.481
# 0
# Test_Loss:  0.101 | Accuracy:  0.482
# 0
# Test_Loss:  0.101 | Accuracy:  0.482
# 0
# Test_Loss:  0.101 | Accuracy:  0.482
# 0
# Test_Loss:  0.101 | Accuracy:  0.482
# 0
# Test_Loss:  0.101 | Accuracy:  0.482
# 0
# Test_Loss:  0.101 | Accuracy:  0.483
# 0
# Test_Loss:  0.101 | Accuracy:  0.483
# 0
# Test_Loss:  0.101 | Accuracy:  0.483
# 0
# Test_Loss:  0.101 | Accuracy:  0.483
# 0
# Test_Loss:  0.101 | Accuracy:  0.483
# 0
# Test_Loss:  0.101 | Accuracy:  0.484
# 0
# Test_Loss:  0.101 | Accuracy:  0.484
# 0
# Test_Loss:  0.101 | Accuracy:  0.484
# 0
# Test_Loss:  0.101 | Accuracy:  0.484
# 0
# Test_Loss:  0.101 | Accuracy:  0.484
# 0
# Test_Loss:  0.101 | Accuracy:  0.485
# 0
# Test_Loss:  0.101 | Accuracy:  0.485
# 0
# Test_Loss:  0.101 | Accuracy:  0.485
# 0
# Test_Loss:  0.102 | Accuracy:  0.485
# 0
# Test_Loss:  0.102 | Accuracy:  0.485
# 0
# Test_Loss:  0.102 | Accuracy:  0.485
# 0
# Test_Loss:  0.102 | Accuracy:  0.486
# 0
# Test_Loss:  0.102 | Accuracy:  0.486
# 0
# Test_Loss:  0.102 | Accuracy:  0.486
# 0
# Test_Loss:  0.102 | Accuracy:  0.486
# 0
# Test_Loss:  0.102 | Accuracy:  0.486
# 0
# Test_Loss:  0.102 | Accuracy:  0.487
# 0
# Test_Loss:  0.102 | Accuracy:  0.487
# 0
# Test_Loss:  0.102 | Accuracy:  0.487
# 0
# Test_Loss:  0.102 | Accuracy:  0.487
# 0
# Test_Loss:  0.102 | Accuracy:  0.487
# 0
# Test_Loss:  0.102 | Accuracy:  0.488
# 0
# Test_Loss:  0.102 | Accuracy:  0.488
# 0
# Test_Loss:  0.102 | Accuracy:  0.488
# 0
# Test_Loss:  0.102 | Accuracy:  0.488
# 0
# Test_Loss:  0.102 | Accuracy:  0.488
# 0
# Test_Loss:  0.102 | Accuracy:  0.489
# 0
# Test_Loss:  0.102 | Accuracy:  0.489
# 0
# Test_Loss:  0.103 | Accuracy:  0.489
# 0
# Test_Loss:  0.103 | Accuracy:  0.489
# 0
# Test_Loss:  0.103 | Accuracy:  0.489
# 0
# Test_Loss:  0.103 | Accuracy:  0.489
# 0
# Test_Loss:  0.103 | Accuracy:  0.490
# 0
# Test_Loss:  0.103 | Accuracy:  0.490
# 0
# Test_Loss:  0.103 | Accuracy:  0.490
# 0
# Test_Loss:  0.103 | Accuracy:  0.490
# 0
# Test_Loss:  0.103 | Accuracy:  0.490
# 0
# Test_Loss:  0.103 | Accuracy:  0.491
# 0
# Test_Loss:  0.103 | Accuracy:  0.491
# 0
# Test_Loss:  0.103 | Accuracy:  0.491
# 0
# Test_Loss:  0.103 | Accuracy:  0.491
# 0
# Test_Loss:  0.103 | Accuracy:  0.491
# 0
# Test_Loss:  0.103 | Accuracy:  0.492
# 0
# Test_Loss:  0.103 | Accuracy:  0.492
# 0
# Test_Loss:  0.103 | Accuracy:  0.492
# 0
# Test_Loss:  0.103 | Accuracy:  0.492
# 0
# Test_Loss:  0.104 | Accuracy:  0.492
# 0
# Test_Loss:  0.104 | Accuracy:  0.492
# 0
# Test_Loss:  0.104 | Accuracy:  0.493
# 0
# Test_Loss:  0.104 | Accuracy:  0.493
# 0
# Test_Loss:  0.104 | Accuracy:  0.493
# 0
# Test_Loss:  0.104 | Accuracy:  0.493
# 0
# Test_Loss:  0.104 | Accuracy:  0.493
# 0
# Test_Loss:  0.104 | Accuracy:  0.494
# 0
# Test_Loss:  0.104 | Accuracy:  0.494
# 0
# Test_Loss:  0.104 | Accuracy:  0.494
# 0
# Test_Loss:  0.104 | Accuracy:  0.494
# 0
# Test_Loss:  0.104 | Accuracy:  0.494
# 0
# Test_Loss:  0.104 | Accuracy:  0.495
# 0
# Test_Loss:  0.104 | Accuracy:  0.495
# 0
# Test_Loss:  0.104 | Accuracy:  0.495
# 0
# Test_Loss:  0.104 | Accuracy:  0.495
# 0
# Test_Loss:  0.104 | Accuracy:  0.495
# 0
# Test_Loss:  0.104 | Accuracy:  0.496
# 0
# Test_Loss:  0.104 | Accuracy:  0.496
# 0
# Test_Loss:  0.105 | Accuracy:  0.496
# 0
# Test_Loss:  0.105 | Accuracy:  0.496
# 0
# Test_Loss:  0.105 | Accuracy:  0.496
# 0
# Test_Loss:  0.105 | Accuracy:  0.497
# 0
# Test_Loss:  0.105 | Accuracy:  0.497
# 0
# Test_Loss:  0.105 | Accuracy:  0.497
# 0
# Test_Loss:  0.105 | Accuracy:  0.497
# 0
# Test_Loss:  0.105 | Accuracy:  0.497
# 0
# Test_Loss:  0.105 | Accuracy:  0.497
# 0
# Test_Loss:  0.105 | Accuracy:  0.498
# 0
# Test_Loss:  0.105 | Accuracy:  0.498
# 0
# Test_Loss:  0.105 | Accuracy:  0.498
# 0
# Test_Loss:  0.105 | Accuracy:  0.498
# 0
# Test_Loss:  0.105 | Accuracy:  0.499
# 0
# Test_Loss:  0.105 | Accuracy:  0.499
# 0
# Test_Loss:  0.105 | Accuracy:  0.499
# 0
# Test_Loss:  0.105 | Accuracy:  0.499
# 0
# Test_Loss:  0.105 | Accuracy:  0.499
# 0
# Test_Loss:  0.105 | Accuracy:  0.500
# 0
# Test_Loss:  0.105 | Accuracy:  0.500
# 0
# Test_Loss:  0.105 | Accuracy:  0.500
# 0
# Test_Loss:  0.105 | Accuracy:  0.500
# 0
# Test_Loss:  0.105 | Accuracy:  0.500
# 0
# Test_Loss:  0.105 | Accuracy:  0.501
# 0
# Test_Loss:  0.105 | Accuracy:  0.501
# 0
# Test_Loss:  0.105 | Accuracy:  0.501
# 0
# Test_Loss:  0.105 | Accuracy:  0.501
# 0
# Test_Loss:  0.105 | Accuracy:  0.501
# 0
# Test_Loss:  0.105 | Accuracy:  0.502
# 0
# Test_Loss:  0.105 | Accuracy:  0.502
# 0
# Test_Loss:  0.105 | Accuracy:  0.502
# 0
# Test_Loss:  0.105 | Accuracy:  0.502
# 0
# Test_Loss:  0.105 | Accuracy:  0.502
# 0
# Test_Loss:  0.106 | Accuracy:  0.503
# 0
# Test_Loss:  0.106 | Accuracy:  0.503
# 0
# Test_Loss:  0.106 | Accuracy:  0.503
# 0
# Test_Loss:  0.106 | Accuracy:  0.503
# 0
# Test_Loss:  0.106 | Accuracy:  0.503
# 0
# Test_Loss:  0.106 | Accuracy:  0.504
# 0
# Test_Loss:  0.106 | Accuracy:  0.504
# 0
# Test_Loss:  0.106 | Accuracy:  0.504
# 0
# Test_Loss:  0.106 | Accuracy:  0.504
# 0
# Test_Loss:  0.106 | Accuracy:  0.504
# 0
# Test_Loss:  0.106 | Accuracy:  0.505
# 0
# Test_Loss:  0.106 | Accuracy:  0.505
# 0
# Test_Loss:  0.106 | Accuracy:  0.505
# 0
# Test_Loss:  0.106 | Accuracy:  0.505
# 0
# Test_Loss:  0.106 | Accuracy:  0.505
# 0
# Test_Loss:  0.106 | Accuracy:  0.506
# 0
# Test_Loss:  0.106 | Accuracy:  0.506
# 0
# Test_Loss:  0.106 | Accuracy:  0.506
# 0
# Test_Loss:  0.106 | Accuracy:  0.506
# 0
# Test_Loss:  0.106 | Accuracy:  0.506
# 0
# Test_Loss:  0.106 | Accuracy:  0.507
# 0
# Test_Loss:  0.106 | Accuracy:  0.507
# 0
# Test_Loss:  0.106 | Accuracy:  0.507
# 0
# Test_Loss:  0.106 | Accuracy:  0.507
# 0
# Test_Loss:  0.106 | Accuracy:  0.507
# 0
# Test_Loss:  0.106 | Accuracy:  0.508
# 0
# Test_Loss:  0.106 | Accuracy:  0.508
# 0
# Test_Loss:  0.106 | Accuracy:  0.508
# 0
# Test_Loss:  0.107 | Accuracy:  0.508
# 0
# Test_Loss:  0.107 | Accuracy:  0.508
# 0
# Test_Loss:  0.107 | Accuracy:  0.508
# 0
# Test_Loss:  0.107 | Accuracy:  0.509
# 0
# Test_Loss:  0.107 | Accuracy:  0.509
# 0
# Test_Loss:  0.107 | Accuracy:  0.509
# 0
# Test_Loss:  0.107 | Accuracy:  0.509
# 0
# Test_Loss:  0.107 | Accuracy:  0.509
# 0
# Test_Loss:  0.107 | Accuracy:  0.510
# 0
# Test_Loss:  0.107 | Accuracy:  0.510
# 0
# Test_Loss:  0.107 | Accuracy:  0.510
# 0
# Test_Loss:  0.107 | Accuracy:  0.510
# 0
# Test_Loss:  0.107 | Accuracy:  0.510
# 0
# Test_Loss:  0.107 | Accuracy:  0.511
# 0
# Test_Loss:  0.107 | Accuracy:  0.511
# 0
# Test_Loss:  0.107 | Accuracy:  0.511
# 0
# Test_Loss:  0.107 | Accuracy:  0.511
# 0
# Test_Loss:  0.107 | Accuracy:  0.511
# 0
# Test_Loss:  0.107 | Accuracy:  0.512
# 0
# Test_Loss:  0.107 | Accuracy:  0.512
# 0
# Test_Loss:  0.107 | Accuracy:  0.512
# 0
# Test_Loss:  0.107 | Accuracy:  0.512
# 0
# Test_Loss:  0.107 | Accuracy:  0.512
# 0
# Test_Loss:  0.107 | Accuracy:  0.513
# 0
# Test_Loss:  0.107 | Accuracy:  0.513
# 0
# Test_Loss:  0.107 | Accuracy:  0.513
# 0
# Test_Loss:  0.107 | Accuracy:  0.513
# 0
# Test_Loss:  0.108 | Accuracy:  0.513
# 0
# Test_Loss:  0.108 | Accuracy:  0.514
# 0
# Test_Loss:  0.108 | Accuracy:  0.514
# 0
# Test_Loss:  0.108 | Accuracy:  0.514
# 0
# Test_Loss:  0.108 | Accuracy:  0.514
# 0
# Test_Loss:  0.108 | Accuracy:  0.514
# 0
# Test_Loss:  0.108 | Accuracy:  0.515
# 0
# Test_Loss:  0.108 | Accuracy:  0.515
# 0
# Test_Loss:  0.108 | Accuracy:  0.515
# 0
# Test_Loss:  0.108 | Accuracy:  0.515
# 0
# Test_Loss:  0.108 | Accuracy:  0.515
# 0
# Test_Loss:  0.108 | Accuracy:  0.515
# 0
# Test_Loss:  0.108 | Accuracy:  0.516
# 0
# Test_Loss:  0.108 | Accuracy:  0.516
# 0
# Test_Loss:  0.108 | Accuracy:  0.516
# 0
# Test_Loss:  0.108 | Accuracy:  0.516
# 0
# Test_Loss:  0.108 | Accuracy:  0.517
# 0
# Test_Loss:  0.108 | Accuracy:  0.517
# 0
# Test_Loss:  0.108 | Accuracy:  0.517
# 0
# Test_Loss:  0.108 | Accuracy:  0.517
# 0
# Test_Loss:  0.108 | Accuracy:  0.517
# 0
# Test_Loss:  0.108 | Accuracy:  0.518
# 0
# Test_Loss:  0.108 | Accuracy:  0.518
# 0
# Test_Loss:  0.108 | Accuracy:  0.518
# 0
# Test_Loss:  0.109 | Accuracy:  0.518
# 0
# Test_Loss:  0.109 | Accuracy:  0.518
# 0
# Test_Loss:  0.109 | Accuracy:  0.518
# 0
# Test_Loss:  0.109 | Accuracy:  0.519
# 0
# Test_Loss:  0.109 | Accuracy:  0.519
# 0
# Test_Loss:  0.109 | Accuracy:  0.519
# 0
# Test_Loss:  0.109 | Accuracy:  0.519
# 0
# Test_Loss:  0.109 | Accuracy:  0.519
# 0
# Test_Loss:  0.109 | Accuracy:  0.520
# 0
# Test_Loss:  0.109 | Accuracy:  0.520
# 0
# Test_Loss:  0.109 | Accuracy:  0.520
# 0
# Test_Loss:  0.109 | Accuracy:  0.520
# 0
# Test_Loss:  0.109 | Accuracy:  0.520
# 0
# Test_Loss:  0.109 | Accuracy:  0.521
# 0
# Test_Loss:  0.109 | Accuracy:  0.521
# 0
# Test_Loss:  0.109 | Accuracy:  0.521
# 0
# Test_Loss:  0.109 | Accuracy:  0.521
# 0
# Test_Loss:  0.109 | Accuracy:  0.521
# 0
# Test_Loss:  0.109 | Accuracy:  0.522
# 0
# Test_Loss:  0.109 | Accuracy:  0.522
# 0
# Test_Loss:  0.109 | Accuracy:  0.522
# 0
# Test_Loss:  0.109 | Accuracy:  0.522
# 0
# Test_Loss:  0.109 | Accuracy:  0.522
# 0
# Test_Loss:  0.109 | Accuracy:  0.523
# 0
# Test_Loss:  0.110 | Accuracy:  0.523
# 0
# Test_Loss:  0.110 | Accuracy:  0.523
# 0
# Test_Loss:  0.110 | Accuracy:  0.523
# 0
# Test_Loss:  0.110 | Accuracy:  0.523
# 0
# Test_Loss:  0.110 | Accuracy:  0.523
# 0
# Test_Loss:  0.110 | Accuracy:  0.524
# 0
# Test_Loss:  0.110 | Accuracy:  0.524
# 0
# Test_Loss:  0.110 | Accuracy:  0.524
# 0
# Test_Loss:  0.110 | Accuracy:  0.524
# 0
# Test_Loss:  0.110 | Accuracy:  0.524
# 0
# Test_Loss:  0.110 | Accuracy:  0.525
# 0
# Test_Loss:  0.110 | Accuracy:  0.525
# 0
# Test_Loss:  0.110 | Accuracy:  0.525
# 0
# Test_Loss:  0.111 | Accuracy:  0.525
# 0
# Test_Loss:  0.111 | Accuracy:  0.525
# 0
# Test_Loss:  0.111 | Accuracy:  0.526
# 0
# Test_Loss:  0.111 | Accuracy:  0.526
# 0
# Test_Loss:  0.111 | Accuracy:  0.526
# 0
# Test_Loss:  0.111 | Accuracy:  0.526
# 0
# Test_Loss:  0.111 | Accuracy:  0.526
# 0
# Test_Loss:  0.111 | Accuracy:  0.527
# 0
# Test_Loss:  0.111 | Accuracy:  0.527
# 0
# Test_Loss:  0.111 | Accuracy:  0.527
# 0
# Test_Loss:  0.111 | Accuracy:  0.527
# 0
# Test_Loss:  0.111 | Accuracy:  0.527
# 0
# Test_Loss:  0.111 | Accuracy:  0.528
# 0
# Test_Loss:  0.111 | Accuracy:  0.528
# 0
# Test_Loss:  0.111 | Accuracy:  0.528
# 0
# Test_Loss:  0.111 | Accuracy:  0.528
# 0
# Test_Loss:  0.111 | Accuracy:  0.528
# 0
# Test_Loss:  0.111 | Accuracy:  0.529
# 0
# Test_Loss:  0.111 | Accuracy:  0.529
# 0
# Test_Loss:  0.111 | Accuracy:  0.529
# 0
# Test_Loss:  0.111 | Accuracy:  0.529
# 0
# Test_Loss:  0.111 | Accuracy:  0.529
# 0
# Test_Loss:  0.111 | Accuracy:  0.530
# 0
# Test_Loss:  0.111 | Accuracy:  0.530
# 0
# Test_Loss:  0.111 | Accuracy:  0.530
# 0
# Test_Loss:  0.111 | Accuracy:  0.530
# 0
# Test_Loss:  0.111 | Accuracy:  0.530
# 0
# Test_Loss:  0.111 | Accuracy:  0.530
# 0
# Test_Loss:  0.111 | Accuracy:  0.531
# 0
# Test_Loss:  0.111 | Accuracy:  0.531
# 0
# Test_Loss:  0.111 | Accuracy:  0.531
# 0
# Test_Loss:  0.111 | Accuracy:  0.531
# 0
# Test_Loss:  0.111 | Accuracy:  0.532
# 0
# Test_Loss:  0.111 | Accuracy:  0.532
# 0
# Test_Loss:  0.111 | Accuracy:  0.532
# 0
# Test_Loss:  0.111 | Accuracy:  0.532
# 0
# Test_Loss:  0.111 | Accuracy:  0.532
# 0
# Test_Loss:  0.111 | Accuracy:  0.533
# 0
# Test_Loss:  0.112 | Accuracy:  0.533
# 0
# Test_Loss:  0.112 | Accuracy:  0.533
# 0
# Test_Loss:  0.112 | Accuracy:  0.533
# 0
# Test_Loss:  0.112 | Accuracy:  0.533
# 0
# Test_Loss:  0.112 | Accuracy:  0.534
# 0
# Test_Loss:  0.112 | Accuracy:  0.534
# 0
# Test_Loss:  0.112 | Accuracy:  0.534
# 0
# Test_Loss:  0.112 | Accuracy:  0.534
# 0
# Test_Loss:  0.112 | Accuracy:  0.534
# 0
# Test_Loss:  0.112 | Accuracy:  0.535
# 0
# Test_Loss:  0.112 | Accuracy:  0.535
# 0
# Test_Loss:  0.112 | Accuracy:  0.535
# 0
# Test_Loss:  0.112 | Accuracy:  0.535
# 0
# Test_Loss:  0.112 | Accuracy:  0.535
# 0
# Test_Loss:  0.112 | Accuracy:  0.536
# 0
# Test_Loss:  0.112 | Accuracy:  0.536
# 0
# Test_Loss:  0.112 | Accuracy:  0.536
# 0
# Test_Loss:  0.112 | Accuracy:  0.536
# 0
# Test_Loss:  0.112 | Accuracy:  0.536
# 0
# Test_Loss:  0.112 | Accuracy:  0.537
# 0
# Test_Loss:  0.112 | Accuracy:  0.537
# 0
# Test_Loss:  0.112 | Accuracy:  0.537
# 0
# Test_Loss:  0.112 | Accuracy:  0.537
# 0
# Test_Loss:  0.112 | Accuracy:  0.537
# 0
# Test_Loss:  0.112 | Accuracy:  0.538
# 0
# Test_Loss:  0.112 | Accuracy:  0.538
# 0
# Test_Loss:  0.112 | Accuracy:  0.538
# 0
# Test_Loss:  0.112 | Accuracy:  0.538
# 0
# Test_Loss:  0.112 | Accuracy:  0.538
# 0
# Test_Loss:  0.112 | Accuracy:  0.538
# 0
# Test_Loss:  0.113 | Accuracy:  0.539
# 0
# Test_Loss:  0.113 | Accuracy:  0.539
# 0
# Test_Loss:  0.113 | Accuracy:  0.539
# 0
# Test_Loss:  0.113 | Accuracy:  0.539
# 0
# Test_Loss:  0.113 | Accuracy:  0.539
# 0
# Test_Loss:  0.113 | Accuracy:  0.540
# 0
# Test_Loss:  0.113 | Accuracy:  0.540
# 0
# Test_Loss:  0.113 | Accuracy:  0.540
# 0
# Test_Loss:  0.113 | Accuracy:  0.540
# 0
# Test_Loss:  0.113 | Accuracy:  0.540
# 0
# Test_Loss:  0.113 | Accuracy:  0.541
# 0
# Test_Loss:  0.113 | Accuracy:  0.541
# 0
# Test_Loss:  0.113 | Accuracy:  0.541
# 0
# Test_Loss:  0.113 | Accuracy:  0.541
# 0
# Test_Loss:  0.113 | Accuracy:  0.541
# 0
# Test_Loss:  0.113 | Accuracy:  0.542
# 0
# Test_Loss:  0.113 | Accuracy:  0.542
# 0
# Test_Loss:  0.113 | Accuracy:  0.542
# 0
# Test_Loss:  0.113 | Accuracy:  0.542
# 0
# Test_Loss:  0.113 | Accuracy:  0.542
# 0
# Test_Loss:  0.113 | Accuracy:  0.543
# 0
# Test_Loss:  0.113 | Accuracy:  0.543
# 0
# Test_Loss:  0.113 | Accuracy:  0.543
# 0
# Test_Loss:  0.113 | Accuracy:  0.543
# 0
# Test_Loss:  0.113 | Accuracy:  0.543
# 0
# Test_Loss:  0.113 | Accuracy:  0.544
# 0
# Test_Loss:  0.113 | Accuracy:  0.544
# 0
# Test_Loss:  0.114 | Accuracy:  0.544
# 0
# Test_Loss:  0.114 | Accuracy:  0.544
# 0
# Test_Loss:  0.114 | Accuracy:  0.544
# 0
# Test_Loss:  0.114 | Accuracy:  0.545
# 0
# Test_Loss:  0.114 | Accuracy:  0.545
# 0
# Test_Loss:  0.114 | Accuracy:  0.545
# 0
# Test_Loss:  0.114 | Accuracy:  0.545
# 0
# Test_Loss:  0.114 | Accuracy:  0.545
# 0
# Test_Loss:  0.114 | Accuracy:  0.546
# 0
# Test_Loss:  0.114 | Accuracy:  0.546
# 0
# Test_Loss:  0.114 | Accuracy:  0.546
# 0
# Test_Loss:  0.114 | Accuracy:  0.546
# 0
# Test_Loss:  0.114 | Accuracy:  0.546
# 0
# Test_Loss:  0.114 | Accuracy:  0.547
# 0
# Test_Loss:  0.114 | Accuracy:  0.547
# 0
# Test_Loss:  0.114 | Accuracy:  0.547
# 0
# Test_Loss:  0.114 | Accuracy:  0.547
# 0
# Test_Loss:  0.114 | Accuracy:  0.547
# 0
# Test_Loss:  0.114 | Accuracy:  0.547
# 0
# Test_Loss:  0.114 | Accuracy:  0.548
# 0
# Test_Loss:  0.114 | Accuracy:  0.548
# 0
# Test_Loss:  0.114 | Accuracy:  0.548
# 0
# Test_Loss:  0.114 | Accuracy:  0.548
# 0
# Test_Loss:  0.114 | Accuracy:  0.548
# 0
# Test_Loss:  0.114 | Accuracy:  0.549
# 0
# Test_Loss:  0.114 | Accuracy:  0.549
# 0
# Test_Loss:  0.114 | Accuracy:  0.549
# 0
# Test_Loss:  0.114 | Accuracy:  0.549
# 0
# Test_Loss:  0.114 | Accuracy:  0.550
# 0
# Test_Loss:  0.115 | Accuracy:  0.550
# 0
# Test_Loss:  0.115 | Accuracy:  0.550
# 0
# Test_Loss:  0.115 | Accuracy:  0.550
# 0
# Test_Loss:  0.115 | Accuracy:  0.550
# 0
# Test_Loss:  0.115 | Accuracy:  0.551
# 0
# Test_Loss:  0.115 | Accuracy:  0.551
# 0
# Test_Loss:  0.115 | Accuracy:  0.551
# 0
# Test_Loss:  0.115 | Accuracy:  0.551
# 0
# Test_Loss:  0.115 | Accuracy:  0.551
# 0
# Test_Loss:  0.115 | Accuracy:  0.551
# 0
# Test_Loss:  0.115 | Accuracy:  0.552
# 0
# Test_Loss:  0.115 | Accuracy:  0.552
# 0
# Test_Loss:  0.115 | Accuracy:  0.552
# 0
# Test_Loss:  0.116 | Accuracy:  0.552
# 0
# Test_Loss:  0.116 | Accuracy:  0.552
# 0
# Test_Loss:  0.116 | Accuracy:  0.553
# 0
# Test_Loss:  0.116 | Accuracy:  0.553
# 0
# Test_Loss:  0.116 | Accuracy:  0.553
# 0
# Test_Loss:  0.116 | Accuracy:  0.553
# 0
# Test_Loss:  0.116 | Accuracy:  0.553
# 0
# Test_Loss:  0.116 | Accuracy:  0.554
# 0
# Test_Loss:  0.116 | Accuracy:  0.554
# 0
# Test_Loss:  0.116 | Accuracy:  0.554
# 0
# Test_Loss:  0.116 | Accuracy:  0.554
# 0
# Test_Loss:  0.116 | Accuracy:  0.554
# 0
# Test_Loss:  0.116 | Accuracy:  0.555
# 0
# Test_Loss:  0.116 | Accuracy:  0.555
# 0
# Test_Loss:  0.116 | Accuracy:  0.555
# 0
# Test_Loss:  0.116 | Accuracy:  0.555
# 0
# Test_Loss:  0.116 | Accuracy:  0.555
# 0
# Test_Loss:  0.116 | Accuracy:  0.556
# 0
# Test_Loss:  0.116 | Accuracy:  0.556
# 0
# Test_Loss:  0.116 | Accuracy:  0.556
# 0
# Test_Loss:  0.116 | Accuracy:  0.556
# 0
# Test_Loss:  0.116 | Accuracy:  0.556
# 0
# Test_Loss:  0.116 | Accuracy:  0.557
# 0
# Test_Loss:  0.116 | Accuracy:  0.557
# 0
# Test_Loss:  0.116 | Accuracy:  0.557
# 0
# Test_Loss:  0.117 | Accuracy:  0.557
# 0
# Test_Loss:  0.117 | Accuracy:  0.557
# 0
# Test_Loss:  0.117 | Accuracy:  0.558
# 0
# Test_Loss:  0.117 | Accuracy:  0.558
# 0
# Test_Loss:  0.117 | Accuracy:  0.558
# 0
# Test_Loss:  0.117 | Accuracy:  0.558
# 0
# Test_Loss:  0.117 | Accuracy:  0.558
# 0
# Test_Loss:  0.117 | Accuracy:  0.558
# 0
# Test_Loss:  0.117 | Accuracy:  0.559
# 0
# Test_Loss:  0.117 | Accuracy:  0.559
# 0
# Test_Loss:  0.117 | Accuracy:  0.559
# 0
# Test_Loss:  0.117 | Accuracy:  0.559
# 0
# Test_Loss:  0.117 | Accuracy:  0.560
# 0
# Test_Loss:  0.117 | Accuracy:  0.560
# 0
# Test_Loss:  0.117 | Accuracy:  0.560
# 0
# Test_Loss:  0.117 | Accuracy:  0.560
# 0
# Test_Loss:  0.117 | Accuracy:  0.560
# 0
# Test_Loss:  0.117 | Accuracy:  0.561
# 0
# Test_Loss:  0.117 | Accuracy:  0.561
# 0
# Test_Loss:  0.117 | Accuracy:  0.561
# 0
# Test_Loss:  0.117 | Accuracy:  0.561
# 0
# Test_Loss:  0.117 | Accuracy:  0.561
# 0
# Test_Loss:  0.117 | Accuracy:  0.561
# 0
# Test_Loss:  0.117 | Accuracy:  0.562
# 0
# Test_Loss:  0.117 | Accuracy:  0.562
# 0
# Test_Loss:  0.117 | Accuracy:  0.562
# 0
# Test_Loss:  0.117 | Accuracy:  0.562
# 0
# Test_Loss:  0.117 | Accuracy:  0.562
# 0
# Test_Loss:  0.117 | Accuracy:  0.563
# 0
# Test_Loss:  0.117 | Accuracy:  0.563
# 0
# Test_Loss:  0.117 | Accuracy:  0.563
# 0
# Test_Loss:  0.117 | Accuracy:  0.563
# 0
# Test_Loss:  0.117 | Accuracy:  0.564
# 0
# Test_Loss:  0.117 | Accuracy:  0.564
# 0
# Test_Loss:  0.117 | Accuracy:  0.564
# 0
# Test_Loss:  0.117 | Accuracy:  0.564
# 0
# Test_Loss:  0.117 | Accuracy:  0.564
# 0
# Test_Loss:  0.117 | Accuracy:  0.565
# 0
# Test_Loss:  0.117 | Accuracy:  0.565
# 0
# Test_Loss:  0.117 | Accuracy:  0.565
# 0
# Test_Loss:  0.118 | Accuracy:  0.565
# 0
# Test_Loss:  0.118 | Accuracy:  0.565
# 0
# Test_Loss:  0.118 | Accuracy:  0.566
# 0
# Test_Loss:  0.118 | Accuracy:  0.566
# 0
# Test_Loss:  0.118 | Accuracy:  0.566
# 0
# Test_Loss:  0.118 | Accuracy:  0.566
# 0
# Test_Loss:  0.118 | Accuracy:  0.566
# 0
# Test_Loss:  0.118 | Accuracy:  0.566
# 0
# Test_Loss:  0.118 | Accuracy:  0.567
# 0
# Test_Loss:  0.118 | Accuracy:  0.567
# 0
# Test_Loss:  0.118 | Accuracy:  0.567
# 0
# Test_Loss:  0.118 | Accuracy:  0.567
# 0
# Test_Loss:  0.118 | Accuracy:  0.567
# 0
# Test_Loss:  0.118 | Accuracy:  0.568
# 0
# Test_Loss:  0.119 | Accuracy:  0.568
# 0
# Test_Loss:  0.119 | Accuracy:  0.568
# 0
# Test_Loss:  0.119 | Accuracy:  0.568
# 0
# Test_Loss:  0.119 | Accuracy:  0.568
# 0
# Test_Loss:  0.119 | Accuracy:  0.568
# 0
# Test_Loss:  0.119 | Accuracy:  0.569
# 0
# Test_Loss:  0.119 | Accuracy:  0.569
# 0
# Test_Loss:  0.119 | Accuracy:  0.569
# 0
# Test_Loss:  0.119 | Accuracy:  0.569
# 0
# Test_Loss:  0.119 | Accuracy:  0.570
# 0
# Test_Loss:  0.119 | Accuracy:  0.570
# 0
# Test_Loss:  0.119 | Accuracy:  0.570
# 0
# Test_Loss:  0.119 | Accuracy:  0.570
# 0
# Test_Loss:  0.119 | Accuracy:  0.570
# 0
# Test_Loss:  0.119 | Accuracy:  0.570
# 0
# Test_Loss:  0.119 | Accuracy:  0.571
# 0
# Test_Loss:  0.119 | Accuracy:  0.571
# 0
# Test_Loss:  0.119 | Accuracy:  0.571
# 0
# Test_Loss:  0.119 | Accuracy:  0.571
# 0
# Test_Loss:  0.119 | Accuracy:  0.572
# 0
# Test_Loss:  0.119 | Accuracy:  0.572
# 0
# Test_Loss:  0.119 | Accuracy:  0.572
# 0
# Test_Loss:  0.119 | Accuracy:  0.572
# 0
# Test_Loss:  0.119 | Accuracy:  0.572
# 0
# Test_Loss:  0.119 | Accuracy:  0.573
# 0
# Test_Loss:  0.119 | Accuracy:  0.573
# 0
# Test_Loss:  0.119 | Accuracy:  0.573
# 0
# Test_Loss:  0.119 | Accuracy:  0.573
# 0
# Test_Loss:  0.119 | Accuracy:  0.573
# 0
# Test_Loss:  0.119 | Accuracy:  0.574
# 0
# Test_Loss:  0.119 | Accuracy:  0.574
# 0
# Test_Loss:  0.119 | Accuracy:  0.574
# 0
# Test_Loss:  0.119 | Accuracy:  0.574
# 0
# Test_Loss:  0.119 | Accuracy:  0.574
# 0
# Test_Loss:  0.119 | Accuracy:  0.575
# 0
# Test_Loss:  0.119 | Accuracy:  0.575
# 0
# Test_Loss:  0.119 | Accuracy:  0.575
# 0
# Test_Loss:  0.120 | Accuracy:  0.575
# 0
# Test_Loss:  0.120 | Accuracy:  0.575
# 0
# Test_Loss:  0.120 | Accuracy:  0.576
# 0
# Test_Loss:  0.120 | Accuracy:  0.576
# 0
# Test_Loss:  0.120 | Accuracy:  0.576
# 0
# Test_Loss:  0.120 | Accuracy:  0.576
# 0
# Test_Loss:  0.120 | Accuracy:  0.576
# 0
# Test_Loss:  0.120 | Accuracy:  0.577
# 0
# Test_Loss:  0.120 | Accuracy:  0.577
# 0
# Test_Loss:  0.120 | Accuracy:  0.577
# 0
# Test_Loss:  0.120 | Accuracy:  0.577
# 0
# Test_Loss:  0.120 | Accuracy:  0.577
# 0
# Test_Loss:  0.120 | Accuracy:  0.577
# 0
# Test_Loss:  0.120 | Accuracy:  0.578
# 0
# Test_Loss:  0.120 | Accuracy:  0.578
# 0
# Test_Loss:  0.120 | Accuracy:  0.578
# 0
# Test_Loss:  0.120 | Accuracy:  0.578
# 0
# Test_Loss:  0.120 | Accuracy:  0.578
# 0
# Test_Loss:  0.120 | Accuracy:  0.579
# 0
# Test_Loss:  0.120 | Accuracy:  0.579
# 0
# Test_Loss:  0.120 | Accuracy:  0.579
# 0
# Test_Loss:  0.120 | Accuracy:  0.579
# 0
# Test_Loss:  0.120 | Accuracy:  0.579
# 0
# Test_Loss:  0.121 | Accuracy:  0.580
# 0
# Test_Loss:  0.121 | Accuracy:  0.580
# 0
# Test_Loss:  0.121 | Accuracy:  0.580
# 0
# Test_Loss:  0.121 | Accuracy:  0.580
# 0
# Test_Loss:  0.121 | Accuracy:  0.580
# 0
# Test_Loss:  0.121 | Accuracy:  0.581
# 0
# Test_Loss:  0.121 | Accuracy:  0.581
# 0
# Test_Loss:  0.121 | Accuracy:  0.581
# 0
# Test_Loss:  0.121 | Accuracy:  0.581
# 0
# Test_Loss:  0.121 | Accuracy:  0.581
# 0
# Test_Loss:  0.121 | Accuracy:  0.581
# 0
# Test_Loss:  0.121 | Accuracy:  0.582
# 0
# Test_Loss:  0.121 | Accuracy:  0.582
# 0
# Test_Loss:  0.121 | Accuracy:  0.582
# 0
# Test_Loss:  0.121 | Accuracy:  0.582
# 0
# Test_Loss:  0.121 | Accuracy:  0.583
# 0
# Test_Loss:  0.121 | Accuracy:  0.583
# 0
# Test_Loss:  0.121 | Accuracy:  0.583
# 0
# Test_Loss:  0.121 | Accuracy:  0.583
# 0
# Test_Loss:  0.121 | Accuracy:  0.583
# 0
# Test_Loss:  0.121 | Accuracy:  0.584
# 0
# Test_Loss:  0.121 | Accuracy:  0.584
# 0
# Test_Loss:  0.121 | Accuracy:  0.584
# 0
# Test_Loss:  0.121 | Accuracy:  0.584
# 0
# Test_Loss:  0.121 | Accuracy:  0.584
# 0
# Test_Loss:  0.121 | Accuracy:  0.584
# 0
# Test_Loss:  0.122 | Accuracy:  0.585
# 0
# Test_Loss:  0.122 | Accuracy:  0.585
# 0
# Test_Loss:  0.122 | Accuracy:  0.585
# 0
# Test_Loss:  0.122 | Accuracy:  0.585
# 0
# Test_Loss:  0.122 | Accuracy:  0.585
# 0
# Test_Loss:  0.122 | Accuracy:  0.586
# 0
# Test_Loss:  0.122 | Accuracy:  0.586
# 0
# Test_Loss:  0.122 | Accuracy:  0.586
# 0
# Test_Loss:  0.122 | Accuracy:  0.586
# 0
# Test_Loss:  0.122 | Accuracy:  0.586
# 0
# Test_Loss:  0.122 | Accuracy:  0.587
# 0
# Test_Loss:  0.122 | Accuracy:  0.587
# 0
# Test_Loss:  0.122 | Accuracy:  0.587
# 0
# Test_Loss:  0.122 | Accuracy:  0.587
# 0
# Test_Loss:  0.122 | Accuracy:  0.587
# 0
# Test_Loss:  0.122 | Accuracy:  0.588
# 0
# Test_Loss:  0.122 | Accuracy:  0.588
# 0
# Test_Loss:  0.122 | Accuracy:  0.588
# 0
# Test_Loss:  0.122 | Accuracy:  0.588
# 0
# Test_Loss:  0.122 | Accuracy:  0.588
# 0
# Test_Loss:  0.123 | Accuracy:  0.588
# 0
# Test_Loss:  0.123 | Accuracy:  0.589
# 0
# Test_Loss:  0.123 | Accuracy:  0.589
# 0
# Test_Loss:  0.123 | Accuracy:  0.589
# 0
# Test_Loss:  0.123 | Accuracy:  0.589
# 0
# Test_Loss:  0.123 | Accuracy:  0.590
# 0
# Test_Loss:  0.123 | Accuracy:  0.590
# 0
# Test_Loss:  0.123 | Accuracy:  0.590
# 0
# Test_Loss:  0.123 | Accuracy:  0.590
# 0
# Test_Loss:  0.123 | Accuracy:  0.590
# 0
# Test_Loss:  0.123 | Accuracy:  0.591
# 0
# Test_Loss:  0.123 | Accuracy:  0.591
# 0
# Test_Loss:  0.123 | Accuracy:  0.591
# 0
# Test_Loss:  0.123 | Accuracy:  0.591
# 0
# Test_Loss:  0.123 | Accuracy:  0.591
# 0
# Test_Loss:  0.123 | Accuracy:  0.591
# 0
# Test_Loss:  0.123 | Accuracy:  0.592
# 0
# Test_Loss:  0.123 | Accuracy:  0.592
# 0
# Test_Loss:  0.123 | Accuracy:  0.592
# 0
# Test_Loss:  0.123 | Accuracy:  0.592
# 0
# Test_Loss:  0.123 | Accuracy:  0.592
# 0
# Test_Loss:  0.123 | Accuracy:  0.593
# 0
# Test_Loss:  0.124 | Accuracy:  0.593
# 0
# Test_Loss:  0.124 | Accuracy:  0.593
# 0
# Test_Loss:  0.124 | Accuracy:  0.593
# 0
# Test_Loss:  0.124 | Accuracy:  0.593
# 0
# Test_Loss:  0.124 | Accuracy:  0.594
# 0
# Test_Loss:  0.124 | Accuracy:  0.594
# 0
# Test_Loss:  0.124 | Accuracy:  0.594
# 0
# Test_Loss:  0.124 | Accuracy:  0.594
# 0
# Test_Loss:  0.124 | Accuracy:  0.594
# 0
# Test_Loss:  0.124 | Accuracy:  0.595
# 0
# Test_Loss:  0.124 | Accuracy:  0.595
# 0
# Test_Loss:  0.124 | Accuracy:  0.595
# 0
# Test_Loss:  0.124 | Accuracy:  0.595
# 0
# Test_Loss:  0.124 | Accuracy:  0.595
# 0
# Test_Loss:  0.124 | Accuracy:  0.596
# 0
# Test_Loss:  0.124 | Accuracy:  0.596
# 0
# Test_Loss:  0.124 | Accuracy:  0.596
# 0
# Test_Loss:  0.125 | Accuracy:  0.596
# 0
# Test_Loss:  0.125 | Accuracy:  0.596
# 0
# Test_Loss:  0.125 | Accuracy:  0.596
# 0
# Test_Loss:  0.125 | Accuracy:  0.597
# 0
# Test_Loss:  0.125 | Accuracy:  0.597
# 0
# Test_Loss:  0.125 | Accuracy:  0.597
# 0
# Test_Loss:  0.125 | Accuracy:  0.597
# 0
# Test_Loss:  0.125 | Accuracy:  0.597
# 0
# Test_Loss:  0.125 | Accuracy:  0.598
# 0
# Test_Loss:  0.125 | Accuracy:  0.598
# 0
# Test_Loss:  0.125 | Accuracy:  0.598
# 0
# Test_Loss:  0.125 | Accuracy:  0.598
# 0
# Test_Loss:  0.125 | Accuracy:  0.598
# 0
# Test_Loss:  0.125 | Accuracy:  0.599
# 0
# Test_Loss:  0.125 | Accuracy:  0.599
# 0
# Test_Loss:  0.125 | Accuracy:  0.599
# 0
# Test_Loss:  0.125 | Accuracy:  0.599
# 0
# Test_Loss:  0.125 | Accuracy:  0.599
# 0
# Test_Loss:  0.125 | Accuracy:  0.600
# 0
# Test_Loss:  0.125 | Accuracy:  0.600
# 0
# Test_Loss:  0.125 | Accuracy:  0.600
# 0
# Test_Loss:  0.125 | Accuracy:  0.600
# 0
# Test_Loss:  0.125 | Accuracy:  0.600
# 0
# Test_Loss:  0.125 | Accuracy:  0.601
# 0
# Test_Loss:  0.125 | Accuracy:  0.601
# 0
# Test_Loss:  0.125 | Accuracy:  0.601
# 0
# Test_Loss:  0.125 | Accuracy:  0.601
# 0
# Test_Loss:  0.125 | Accuracy:  0.601
# 0
# Test_Loss:  0.126 | Accuracy:  0.602
# 0
# Test_Loss:  0.126 | Accuracy:  0.602
# 0
# Test_Loss:  0.126 | Accuracy:  0.602
# 0
# Test_Loss:  0.126 | Accuracy:  0.602
# 0
# Test_Loss:  0.126 | Accuracy:  0.602
# 0
# Test_Loss:  0.126 | Accuracy:  0.603
# 0
# Test_Loss:  0.126 | Accuracy:  0.603
# 0
# Test_Loss:  0.126 | Accuracy:  0.603
# 0
# Test_Loss:  0.126 | Accuracy:  0.603
# 0
# Test_Loss:  0.126 | Accuracy:  0.603
# 0
# Test_Loss:  0.126 | Accuracy:  0.604
# 0
# Test_Loss:  0.126 | Accuracy:  0.604
# 0
# Test_Loss:  0.126 | Accuracy:  0.604
# 0
# Test_Loss:  0.126 | Accuracy:  0.604
# 0
# Test_Loss:  0.126 | Accuracy:  0.604
# 0
# Test_Loss:  0.126 | Accuracy:  0.605
# 0
# Test_Loss:  0.126 | Accuracy:  0.605
# 0
# Test_Loss:  0.126 | Accuracy:  0.605
# 0
# Test_Loss:  0.126 | Accuracy:  0.605
# 0
# Test_Loss:  0.126 | Accuracy:  0.605
# 0
# Test_Loss:  0.126 | Accuracy:  0.606
# 0
# Test_Loss:  0.126 | Accuracy:  0.606
# 0
# Test_Loss:  0.126 | Accuracy:  0.606
# 0
# Test_Loss:  0.126 | Accuracy:  0.606
# 0
# Test_Loss:  0.126 | Accuracy:  0.606
# 0
# Test_Loss:  0.126 | Accuracy:  0.607
# 0
# Test_Loss:  0.126 | Accuracy:  0.607
# 0
# Test_Loss:  0.126 | Accuracy:  0.607
# 0
# Test_Loss:  0.126 | Accuracy:  0.607
# 0
# Test_Loss:  0.126 | Accuracy:  0.607
# 0
# Test_Loss:  0.127 | Accuracy:  0.607
# 0
# Test_Loss:  0.127 | Accuracy:  0.608
# 0
# Test_Loss:  0.127 | Accuracy:  0.608
# 0
# Test_Loss:  0.127 | Accuracy:  0.608
# 0
# Test_Loss:  0.127 | Accuracy:  0.608
# 0
# Test_Loss:  0.127 | Accuracy:  0.608
# 0
# Test_Loss:  0.127 | Accuracy:  0.609
# 0
# Test_Loss:  0.127 | Accuracy:  0.609
# 0
# Test_Loss:  0.127 | Accuracy:  0.609
# 0
# Test_Loss:  0.127 | Accuracy:  0.609
# 0
# Test_Loss:  0.127 | Accuracy:  0.609
# 0
# Test_Loss:  0.127 | Accuracy:  0.610
# 0
# Test_Loss:  0.127 | Accuracy:  0.610
# 0
# Test_Loss:  0.127 | Accuracy:  0.610
# 0
# Test_Loss:  0.127 | Accuracy:  0.610
# 0
# Test_Loss:  0.127 | Accuracy:  0.610
# 0
# Test_Loss:  0.127 | Accuracy:  0.611
# 0
# Test_Loss:  0.127 | Accuracy:  0.611
# 0
# Test_Loss:  0.127 | Accuracy:  0.611
# 0
# Test_Loss:  0.127 | Accuracy:  0.611
# 0
# Test_Loss:  0.127 | Accuracy:  0.612
# 0
# Test_Loss:  0.127 | Accuracy:  0.612
# 0
# Test_Loss:  0.127 | Accuracy:  0.612
# 0
# Test_Loss:  0.127 | Accuracy:  0.612
# 0
# Test_Loss:  0.128 | Accuracy:  0.612
# 0
# Test_Loss:  0.128 | Accuracy:  0.612
# 0
# Test_Loss:  0.128 | Accuracy:  0.613
# 0
# Test_Loss:  0.128 | Accuracy:  0.613
# 0
# Test_Loss:  0.128 | Accuracy:  0.613
# 0
# Test_Loss:  0.128 | Accuracy:  0.613
# 0
# Test_Loss:  0.128 | Accuracy:  0.613
# 0
# Test_Loss:  0.128 | Accuracy:  0.614
# 0
# Test_Loss:  0.128 | Accuracy:  0.614
# 0
# Test_Loss:  0.128 | Accuracy:  0.614
# 0
# Test_Loss:  0.128 | Accuracy:  0.614
# 0
# Test_Loss:  0.128 | Accuracy:  0.614
# 0
# Test_Loss:  0.128 | Accuracy:  0.615
# 0
# Test_Loss:  0.128 | Accuracy:  0.615
# 0
# Test_Loss:  0.128 | Accuracy:  0.615
# 0
# Test_Loss:  0.128 | Accuracy:  0.615
# 0
# Test_Loss:  0.128 | Accuracy:  0.615
# 0
# Test_Loss:  0.128 | Accuracy:  0.616
# 0
# Test_Loss:  0.128 | Accuracy:  0.616
# 0
# Test_Loss:  0.128 | Accuracy:  0.616
# 0
# Test_Loss:  0.128 | Accuracy:  0.616
# 0
# Test_Loss:  0.128 | Accuracy:  0.616
# 0
# Test_Loss:  0.128 | Accuracy:  0.617
# 0
# Test_Loss:  0.128 | Accuracy:  0.617
# 0
# Test_Loss:  0.128 | Accuracy:  0.617
# 0
# Test_Loss:  0.128 | Accuracy:  0.617
# 0
# Test_Loss:  0.128 | Accuracy:  0.617
# 0
# Test_Loss:  0.128 | Accuracy:  0.618
# 0
# Test_Loss:  0.128 | Accuracy:  0.618
# 0
# Test_Loss:  0.128 | Accuracy:  0.618
# 0
# Test_Loss:  0.128 | Accuracy:  0.618
# 0
# Test_Loss:  0.129 | Accuracy:  0.618
# 0
# Test_Loss:  0.129 | Accuracy:  0.619
# 0
# Test_Loss:  0.129 | Accuracy:  0.619
# 0
# Test_Loss:  0.129 | Accuracy:  0.619
# 0
# Test_Loss:  0.129 | Accuracy:  0.619
# 0
# Test_Loss:  0.129 | Accuracy:  0.619
# 0
# Test_Loss:  0.129 | Accuracy:  0.620
# 0
# Test_Loss:  0.129 | Accuracy:  0.620
# 0
# Test_Loss:  0.129 | Accuracy:  0.620
# 0
# Test_Loss:  0.129 | Accuracy:  0.620
# 0
# Test_Loss:  0.129 | Accuracy:  0.620
# 0
# Test_Loss:  0.129 | Accuracy:  0.621
# 0
# Test_Loss:  0.129 | Accuracy:  0.621
# 0
# Test_Loss:  0.129 | Accuracy:  0.621
# 0
# Test_Loss:  0.129 | Accuracy:  0.621
# 0
# Test_Loss:  0.129 | Accuracy:  0.621
# 0
# Test_Loss:  0.129 | Accuracy:  0.621
# 0
# Test_Loss:  0.129 | Accuracy:  0.622
# 0
# Test_Loss:  0.130 | Accuracy:  0.622
# 0
# Test_Loss:  0.130 | Accuracy:  0.622
# 0
# Test_Loss:  0.130 | Accuracy:  0.622
# 0
# Test_Loss:  0.130 | Accuracy:  0.622
# 0
# Test_Loss:  0.130 | Accuracy:  0.623
# 0
# Test_Loss:  0.130 | Accuracy:  0.623
# 0
# Test_Loss:  0.130 | Accuracy:  0.623
# 0
# Test_Loss:  0.130 | Accuracy:  0.623
# 0
# Test_Loss:  0.130 | Accuracy:  0.623
# 0
# Test_Loss:  0.130 | Accuracy:  0.624
# 0
# Test_Loss:  0.130 | Accuracy:  0.624
# 0
# Test_Loss:  0.130 | Accuracy:  0.624
# 0
# Test_Loss:  0.130 | Accuracy:  0.624
# 0
# Test_Loss:  0.130 | Accuracy:  0.624
# 0
# Test_Loss:  0.130 | Accuracy:  0.625
# 0
# Test_Loss:  0.130 | Accuracy:  0.625
# 0
# Test_Loss:  0.130 | Accuracy:  0.625
# 0
# Test_Loss:  0.130 | Accuracy:  0.625
# 0
# Test_Loss:  0.130 | Accuracy:  0.625
# 0
# Test_Loss:  0.130 | Accuracy:  0.626
# 0
# Test_Loss:  0.130 | Accuracy:  0.626
# 0
# Test_Loss:  0.130 | Accuracy:  0.626
# 0
# Test_Loss:  0.130 | Accuracy:  0.626
# 0
# Test_Loss:  0.131 | Accuracy:  0.626
# 0
# Test_Loss:  0.131 | Accuracy:  0.627
# 0
# Test_Loss:  0.131 | Accuracy:  0.627
# 0
# Test_Loss:  0.131 | Accuracy:  0.627
# 0
# Test_Loss:  0.131 | Accuracy:  0.627
# 0
# Test_Loss:  0.131 | Accuracy:  0.627
# 0
# Test_Loss:  0.131 | Accuracy:  0.627
# 0
# Test_Loss:  0.131 | Accuracy:  0.628
# 0
# Test_Loss:  0.131 | Accuracy:  0.628
# 0
# Test_Loss:  0.131 | Accuracy:  0.628
# 0
# Test_Loss:  0.131 | Accuracy:  0.628
# 0
# Test_Loss:  0.131 | Accuracy:  0.629
# 0
# Test_Loss:  0.131 | Accuracy:  0.629
# 0
# Test_Loss:  0.131 | Accuracy:  0.629
# 0
# Test_Loss:  0.131 | Accuracy:  0.629
# 0
# Test_Loss:  0.131 | Accuracy:  0.629
# 0
# Test_Loss:  0.132 | Accuracy:  0.629
# 0
# Test_Loss:  0.132 | Accuracy:  0.630
# 0
# Test_Loss:  0.132 | Accuracy:  0.630
# 0
# Test_Loss:  0.132 | Accuracy:  0.630
# 0
# Test_Loss:  0.132 | Accuracy:  0.630
# 0
# Test_Loss:  0.132 | Accuracy:  0.630
# 0
# Test_Loss:  0.132 | Accuracy:  0.631
# 0
# Test_Loss:  0.132 | Accuracy:  0.631
# 0
# Test_Loss:  0.132 | Accuracy:  0.631
# 0
# Test_Loss:  0.132 | Accuracy:  0.631
# 0
# Test_Loss:  0.132 | Accuracy:  0.631
# 0
# Test_Loss:  0.132 | Accuracy:  0.631
# 0
# Test_Loss:  0.132 | Accuracy:  0.632
# 0
# Test_Loss:  0.132 | Accuracy:  0.632
# 0
# Test_Loss:  0.132 | Accuracy:  0.632
# 0
# Test_Loss:  0.132 | Accuracy:  0.632
# 0
# Test_Loss:  0.132 | Accuracy:  0.632
# 0
# Test_Loss:  0.133 | Accuracy:  0.633
# 0
# Test_Loss:  0.133 | Accuracy:  0.633
# 0
# Test_Loss:  0.133 | Accuracy:  0.633
# 0
# Test_Loss:  0.133 | Accuracy:  0.633
# 0
# Test_Loss:  0.133 | Accuracy:  0.633
# 0
# Test_Loss:  0.133 | Accuracy:  0.634
# 0
# Test_Loss:  0.133 | Accuracy:  0.634
# 0
# Test_Loss:  0.133 | Accuracy:  0.634
# 0
# Test_Loss:  0.133 | Accuracy:  0.634
# 0
# Test_Loss:  0.133 | Accuracy:  0.634
# 0
# Test_Loss:  0.133 | Accuracy:  0.635
# 0
# Test_Loss:  0.133 | Accuracy:  0.635
# 0
# Test_Loss:  0.133 | Accuracy:  0.635
# 0
# Test_Loss:  0.133 | Accuracy:  0.635
# 0
# Test_Loss:  0.133 | Accuracy:  0.635
# 0
# Test_Loss:  0.133 | Accuracy:  0.636
# 0
# Test_Loss:  0.133 | Accuracy:  0.636
# 0
# Test_Loss:  0.133 | Accuracy:  0.636
# 0
# Test_Loss:  0.133 | Accuracy:  0.636
# 0
# Test_Loss:  0.133 | Accuracy:  0.636
# 0
# Test_Loss:  0.133 | Accuracy:  0.637
# 0
# Test_Loss:  0.133 | Accuracy:  0.637
# 0
# Test_Loss:  0.133 | Accuracy:  0.637
# 0
# Test_Loss:  0.133 | Accuracy:  0.637
# 0
# Test_Loss:  0.133 | Accuracy:  0.637
# 0
# Test_Loss:  0.134 | Accuracy:  0.637
# 0
# Test_Loss:  0.134 | Accuracy:  0.638
# 0
# Test_Loss:  0.134 | Accuracy:  0.638
# 0
# Test_Loss:  0.134 | Accuracy:  0.638
# 0
# Test_Loss:  0.134 | Accuracy:  0.638
# 0
# Test_Loss:  0.134 | Accuracy:  0.638
# 0
# Test_Loss:  0.134 | Accuracy:  0.639
# 0
# Test_Loss:  0.134 | Accuracy:  0.639
# 0
# Test_Loss:  0.134 | Accuracy:  0.639
# 0
# Test_Loss:  0.134 | Accuracy:  0.639
# 0
# Test_Loss:  0.134 | Accuracy:  0.639
# 0
# Test_Loss:  0.134 | Accuracy:  0.640
# 0
# Test_Loss:  0.134 | Accuracy:  0.640
# 0
# Test_Loss:  0.134 | Accuracy:  0.640
# 0
# Test_Loss:  0.134 | Accuracy:  0.640
# 0
# Test_Loss:  0.134 | Accuracy:  0.640
# 0
# Test_Loss:  0.134 | Accuracy:  0.641
# 0
# Test_Loss:  0.134 | Accuracy:  0.641
# 0
# Test_Loss:  0.134 | Accuracy:  0.641
# 0
# Test_Loss:  0.134 | Accuracy:  0.641
# 0
# Test_Loss:  0.134 | Accuracy:  0.641
# 0
# Test_Loss:  0.134 | Accuracy:  0.642
# 0
# Test_Loss:  0.134 | Accuracy:  0.642
# 0
# Test_Loss:  0.135 | Accuracy:  0.642
# 0
# Test_Loss:  0.135 | Accuracy:  0.642
# 0
# Test_Loss:  0.135 | Accuracy:  0.642
# 0
# Test_Loss:  0.135 | Accuracy:  0.643
# 0
# Test_Loss:  0.135 | Accuracy:  0.643
# 0
# Test_Loss:  0.135 | Accuracy:  0.643
# 0
# Test_Loss:  0.135 | Accuracy:  0.643
# 0
# Test_Loss:  0.135 | Accuracy:  0.643
# 0
# Test_Loss:  0.135 | Accuracy:  0.643
# 0
# Test_Loss:  0.135 | Accuracy:  0.644
# 0
# Test_Loss:  0.135 | Accuracy:  0.644
# 0
# Test_Loss:  0.135 | Accuracy:  0.644
# 0
# Test_Loss:  0.135 | Accuracy:  0.644
# 0
# Test_Loss:  0.135 | Accuracy:  0.644
# 0
# Test_Loss:  0.135 | Accuracy:  0.645
# 0
# Test_Loss:  0.135 | Accuracy:  0.645
# 0
# Test_Loss:  0.135 | Accuracy:  0.645
# 0
# Test_Loss:  0.135 | Accuracy:  0.645
# 0
# Test_Loss:  0.135 | Accuracy:  0.645
# 0
# Test_Loss:  0.135 | Accuracy:  0.646
# 0
# Test_Loss:  0.135 | Accuracy:  0.646
# 0
# Test_Loss:  0.135 | Accuracy:  0.646
# 0
# Test_Loss:  0.135 | Accuracy:  0.646
# 0
# Test_Loss:  0.135 | Accuracy:  0.647
# 0
# Test_Loss:  0.135 | Accuracy:  0.647
# 0
# Test_Loss:  0.135 | Accuracy:  0.647
# 0
# Test_Loss:  0.135 | Accuracy:  0.647
# 0
# Test_Loss:  0.135 | Accuracy:  0.647
# 0
# Test_Loss:  0.135 | Accuracy:  0.647
# 0
# Test_Loss:  0.136 | Accuracy:  0.648
# 0
# Test_Loss:  0.136 | Accuracy:  0.648
# 0
# Test_Loss:  0.136 | Accuracy:  0.648
# 0
# Test_Loss:  0.136 | Accuracy:  0.648
# 0
# Test_Loss:  0.136 | Accuracy:  0.648
# 0
# Test_Loss:  0.136 | Accuracy:  0.649
# 0
# Test_Loss:  0.136 | Accuracy:  0.649
# 0
# Test_Loss:  0.136 | Accuracy:  0.649
# 0
# Test_Loss:  0.136 | Accuracy:  0.649
# 0
# Test_Loss:  0.136 | Accuracy:  0.649
# 0
# Test_Loss:  0.136 | Accuracy:  0.650
# 0
# Test_Loss:  0.136 | Accuracy:  0.650
# 0
# Test_Loss:  0.136 | Accuracy:  0.650
# 0
# Test_Loss:  0.136 | Accuracy:  0.650
# 0
# Test_Loss:  0.136 | Accuracy:  0.650
# 0
# Test_Loss:  0.136 | Accuracy:  0.651
# 0
# Test_Loss:  0.136 | Accuracy:  0.651
# 0
# Test_Loss:  0.136 | Accuracy:  0.651
# 0
# Test_Loss:  0.136 | Accuracy:  0.651
# 0
# Test_Loss:  0.136 | Accuracy:  0.651
# 0
# Test_Loss:  0.136 | Accuracy:  0.651
# 0
# Test_Loss:  0.137 | Accuracy:  0.652
# 0
# Test_Loss:  0.137 | Accuracy:  0.652
# 0
# Test_Loss:  0.137 | Accuracy:  0.652
# 0
# Test_Loss:  0.137 | Accuracy:  0.652
# 0
# Test_Loss:  0.137 | Accuracy:  0.653
# 0
# Test_Loss:  0.137 | Accuracy:  0.653
# 0
# Test_Loss:  0.137 | Accuracy:  0.653
# 0
# Test_Loss:  0.137 | Accuracy:  0.653
# 0
# Test_Loss:  0.137 | Accuracy:  0.653
# 0
# Test_Loss:  0.137 | Accuracy:  0.653
# 0
# Test_Loss:  0.137 | Accuracy:  0.654
# 0
# Test_Loss:  0.137 | Accuracy:  0.654
# 0
# Test_Loss:  0.137 | Accuracy:  0.654
# 0
# Test_Loss:  0.137 | Accuracy:  0.654
# 0
# Test_Loss:  0.137 | Accuracy:  0.654
# 0
# Test_Loss:  0.137 | Accuracy:  0.655
# 0
# Test_Loss:  0.137 | Accuracy:  0.655
# 0
# Test_Loss:  0.137 | Accuracy:  0.655
# 0
# Test_Loss:  0.137 | Accuracy:  0.655
# 0
# Test_Loss:  0.137 | Accuracy:  0.655
# 0
# Test_Loss:  0.138 | Accuracy:  0.656
# 0
# Test_Loss:  0.138 | Accuracy:  0.656
# 0
# Test_Loss:  0.138 | Accuracy:  0.656
# 0
# Test_Loss:  0.138 | Accuracy:  0.656
# 0
# Test_Loss:  0.138 | Accuracy:  0.656
# 0
# Test_Loss:  0.138 | Accuracy:  0.657
# 0
# Test_Loss:  0.138 | Accuracy:  0.657
# 0
# Test_Loss:  0.138 | Accuracy:  0.657
# 0
# Test_Loss:  0.138 | Accuracy:  0.657
# 0
# Test_Loss:  0.138 | Accuracy:  0.657
# 0
# Test_Loss:  0.138 | Accuracy:  0.658
# 0
# Test_Loss:  0.138 | Accuracy:  0.658
# 0
# Test_Loss:  0.138 | Accuracy:  0.658
# 0
# Test_Loss:  0.138 | Accuracy:  0.658
# 0
# Test_Loss:  0.138 | Accuracy:  0.658
# 0
# Test_Loss:  0.138 | Accuracy:  0.659
# 0
# Test_Loss:  0.138 | Accuracy:  0.659
# 0
# Test_Loss:  0.138 | Accuracy:  0.659
# 0
# Test_Loss:  0.138 | Accuracy:  0.659
# 0
# Test_Loss:  0.138 | Accuracy:  0.659
# 0
# Test_Loss:  0.138 | Accuracy:  0.659
# 0
# Test_Loss:  0.138 | Accuracy:  0.660
# 0
# Test_Loss:  0.138 | Accuracy:  0.660
# 0
# Test_Loss:  0.138 | Accuracy:  0.660
# 0
# Test_Loss:  0.138 | Accuracy:  0.660
# 0
# Test_Loss:  0.138 | Accuracy:  0.660
# 0
# Test_Loss:  0.138 | Accuracy:  0.661
# 0
# Test_Loss:  0.139 | Accuracy:  0.661
# 0
# Test_Loss:  0.139 | Accuracy:  0.661
# 0
# Test_Loss:  0.139 | Accuracy:  0.661
# 0
# Test_Loss:  0.139 | Accuracy:  0.661
# 0
# Test_Loss:  0.139 | Accuracy:  0.662
# 0
# Test_Loss:  0.139 | Accuracy:  0.662
# 0
# Test_Loss:  0.139 | Accuracy:  0.662
# 0
# Test_Loss:  0.139 | Accuracy:  0.662
# 0
# Test_Loss:  0.139 | Accuracy:  0.662
# 0
# Test_Loss:  0.139 | Accuracy:  0.663
# 0
# Test_Loss:  0.139 | Accuracy:  0.663
# 0
# Test_Loss:  0.139 | Accuracy:  0.663
# 0
# Test_Loss:  0.139 | Accuracy:  0.663
# 0
# Test_Loss:  0.139 | Accuracy:  0.663
# 0
# Test_Loss:  0.139 | Accuracy:  0.664
# 0
# Test_Loss:  0.139 | Accuracy:  0.664
# 0
# Test_Loss:  0.139 | Accuracy:  0.664
# 0
# Test_Loss:  0.139 | Accuracy:  0.664
# 0
# Test_Loss:  0.139 | Accuracy:  0.664
# 0
# Test_Loss:  0.139 | Accuracy:  0.665
# 0
# Test_Loss:  0.139 | Accuracy:  0.665
# 0
# Test_Loss:  0.139 | Accuracy:  0.665
# 0
# Test_Loss:  0.139 | Accuracy:  0.665
# 0
# Test_Loss:  0.140 | Accuracy:  0.665
# 0
# Test_Loss:  0.140 | Accuracy:  0.666
# 0
# Test_Loss:  0.140 | Accuracy:  0.666
# 0
# Test_Loss:  0.140 | Accuracy:  0.666
# 0
# Test_Loss:  0.140 | Accuracy:  0.666
# 0
# Test_Loss:  0.140 | Accuracy:  0.666
# 0
# Test_Loss:  0.140 | Accuracy:  0.667
# 0
# Test_Loss:  0.140 | Accuracy:  0.667
# 0
# Test_Loss:  0.140 | Accuracy:  0.667
# 0
# Test_Loss:  0.140 | Accuracy:  0.667
# 0
# Test_Loss:  0.140 | Accuracy:  0.667
# 0
# Test_Loss:  0.140 | Accuracy:  0.667
# 0
# Test_Loss:  0.140 | Accuracy:  0.668
# 0
# Test_Loss:  0.140 | Accuracy:  0.668
# 0
# Test_Loss:  0.140 | Accuracy:  0.668
# 0
# Test_Loss:  0.140 | Accuracy:  0.668
# 0
# Test_Loss:  0.140 | Accuracy:  0.668
# 0
# Test_Loss:  0.140 | Accuracy:  0.669
# 0
# Test_Loss:  0.140 | Accuracy:  0.669
# 0
# Test_Loss:  0.140 | Accuracy:  0.669
# 0
# Test_Loss:  0.140 | Accuracy:  0.669
# 0
# Test_Loss:  0.140 | Accuracy:  0.669
# 0
# Test_Loss:  0.140 | Accuracy:  0.670
# 0
# Test_Loss:  0.140 | Accuracy:  0.670
# 0
# Test_Loss:  0.140 | Accuracy:  0.670
# 0
# Test_Loss:  0.141 | Accuracy:  0.670
# 0
# Test_Loss:  0.141 | Accuracy:  0.670
# 0
# Test_Loss:  0.141 | Accuracy:  0.671
# 0
# Test_Loss:  0.141 | Accuracy:  0.671
# 0
# Test_Loss:  0.141 | Accuracy:  0.671
# 0
# Test_Loss:  0.141 | Accuracy:  0.671
# 0
# Test_Loss:  0.141 | Accuracy:  0.671
# 0
# Test_Loss:  0.141 | Accuracy:  0.672
# 0
# Test_Loss:  0.141 | Accuracy:  0.672
# 0
# Test_Loss:  0.141 | Accuracy:  0.672
# 0
# Test_Loss:  0.141 | Accuracy:  0.672
# 0
# Test_Loss:  0.141 | Accuracy:  0.672
# 0
# Test_Loss:  0.141 | Accuracy:  0.672
# 0
# Test_Loss:  0.141 | Accuracy:  0.673
# 0
# Test_Loss:  0.141 | Accuracy:  0.673
# 0
# Test_Loss:  0.141 | Accuracy:  0.673
# 0
# Test_Loss:  0.141 | Accuracy:  0.673
# 0
# Test_Loss:  0.142 | Accuracy:  0.673
# 0
# Test_Loss:  0.142 | Accuracy:  0.674
# 0
# Test_Loss:  0.142 | Accuracy:  0.674
# 0
# Test_Loss:  0.142 | Accuracy:  0.674
# 0
# Test_Loss:  0.142 | Accuracy:  0.674
# 0
# Test_Loss:  0.142 | Accuracy:  0.674
# 0
# Test_Loss:  0.142 | Accuracy:  0.675
# 0
# Test_Loss:  0.142 | Accuracy:  0.675
# 0
# Test_Loss:  0.142 | Accuracy:  0.675
# 0
# Test_Loss:  0.142 | Accuracy:  0.675
# 0
# Test_Loss:  0.142 | Accuracy:  0.675
# 0
# Test_Loss:  0.142 | Accuracy:  0.676
# 0
# Test_Loss:  0.142 | Accuracy:  0.676
# 0
# Test_Loss:  0.142 | Accuracy:  0.676
# 0
# Test_Loss:  0.142 | Accuracy:  0.676
# 0
# Test_Loss:  0.142 | Accuracy:  0.676
# 0
# Test_Loss:  0.142 | Accuracy:  0.677
# 0
# Test_Loss:  0.142 | Accuracy:  0.677
# 0
# Test_Loss:  0.142 | Accuracy:  0.677
# 0
# Test_Loss:  0.142 | Accuracy:  0.677
# 0
# Test_Loss:  0.142 | Accuracy:  0.677
# 0
# Test_Loss:  0.142 | Accuracy:  0.678
# 0
# Test_Loss:  0.142 | Accuracy:  0.678
# 0
# Test_Loss:  0.142 | Accuracy:  0.678
# 0
# Test_Loss:  0.142 | Accuracy:  0.678
# 0
# Test_Loss:  0.142 | Accuracy:  0.678
# 0
# Test_Loss:  0.142 | Accuracy:  0.679
# 0
# Test_Loss:  0.142 | Accuracy:  0.679
# 0
# Test_Loss:  0.142 | Accuracy:  0.679
# 0
# Test_Loss:  0.142 | Accuracy:  0.679
# 0
# Test_Loss:  0.142 | Accuracy:  0.679
# 0
# Test_Loss:  0.143 | Accuracy:  0.680
# 0
# Test_Loss:  0.143 | Accuracy:  0.680
# 0
# Test_Loss:  0.143 | Accuracy:  0.680
# 0
# Test_Loss:  0.143 | Accuracy:  0.680
# 0
# Test_Loss:  0.143 | Accuracy:  0.680
# 0
# Test_Loss:  0.143 | Accuracy:  0.681
# 0
# Test_Loss:  0.143 | Accuracy:  0.681
# 0
# Test_Loss:  0.143 | Accuracy:  0.681
# 0
# Test_Loss:  0.143 | Accuracy:  0.681
# 0
# Test_Loss:  0.143 | Accuracy:  0.681
# 0
# Test_Loss:  0.143 | Accuracy:  0.682
# 0
# Test_Loss:  0.143 | Accuracy:  0.682
# 0
# Test_Loss:  0.143 | Accuracy:  0.682
# 0
# Test_Loss:  0.143 | Accuracy:  0.682
# 0
# Test_Loss:  0.143 | Accuracy:  0.682
# 0
# Test_Loss:  0.143 | Accuracy:  0.682
# 0
# Test_Loss:  0.143 | Accuracy:  0.683
# 0
# Test_Loss:  0.143 | Accuracy:  0.683
# 0
# Test_Loss:  0.144 | Accuracy:  0.683
# 0
# Test_Loss:  0.144 | Accuracy:  0.683
# 0
# Test_Loss:  0.144 | Accuracy:  0.683
# 0
# Test_Loss:  0.144 | Accuracy:  0.684
# 0
# Test_Loss:  0.144 | Accuracy:  0.684
# 0
# Test_Loss:  0.144 | Accuracy:  0.684
# 0
# Test_Loss:  0.144 | Accuracy:  0.684
# 0
# Test_Loss:  0.144 | Accuracy:  0.684
# 0
# Test_Loss:  0.144 | Accuracy:  0.685
# 0
# Test_Loss:  0.144 | Accuracy:  0.685
# 0
# Test_Loss:  0.144 | Accuracy:  0.685
# 0
# Test_Loss:  0.144 | Accuracy:  0.685
# 0
# Test_Loss:  0.144 | Accuracy:  0.685
# 0
# Test_Loss:  0.144 | Accuracy:  0.686
# 0
# Test_Loss:  0.144 | Accuracy:  0.686
# 0
# Test_Loss:  0.144 | Accuracy:  0.686
# 0
# Test_Loss:  0.144 | Accuracy:  0.686
# 0
# Test_Loss:  0.144 | Accuracy:  0.686
# 0
# ...
# 0
# Test_Loss:  0.179 | Accuracy:  0.857
# 0
# Test_Loss:  0.179 | Accuracy:  0.857
# 0
# Test_Loss:  0.179 | Accuracy:  0.858
# 0
# Test_Loss:  0.179 | Accuracy:  0.858
# 0
# Test_Loss:  0.179 | Accuracy:  0.858
# 0
# Test_Loss:  0.179 | Accuracy:  0.858
# 0
# Test_Loss:  0.179 | Accuracy:  0.858
# 0
# Test_Loss:  0.180 | Accuracy:  0.859
# 0
# Test_Loss:  0.180 | Accuracy:  0.859
# 0
# Test_Loss:  0.180 | Accuracy:  0.859
# 0
# Test_Loss:  0.180 | Accuracy:  0.859
# 0
# Test_Loss:  0.180 | Accuracy:  0.859
# 0
# Test_Loss:  0.180 | Accuracy:  0.860
# 0
# Test_Loss:  0.180 | Accuracy:  0.860
# 0
# Test_Loss:  0.180 | Accuracy:  0.860
# 0
# Test_Loss:  0.180 | Accuracy:  0.860
# 0
# Test_Loss:  0.180 | Accuracy:  0.860
# 0
# Test_Loss:  0.180 | Accuracy:  0.861
# 0
# Test_Loss:  0.180 | Accuracy:  0.861
# 0
# Test_Loss:  0.180 | Accuracy:  0.861
# 0
# Test_Loss:  0.180 | Accuracy:  0.861
# 0
# Test_Loss:  0.180 | Accuracy:  0.861
# 0
# Test_Loss:  0.180 | Accuracy:  0.862
# 0
# Test_Loss:  0.180 | Accuracy:  0.862
# 0
# Test_Loss:  0.181 | Accuracy:  0.862
# 0
# Test_Loss:  0.181 | Accuracy:  0.862
# 0
# Test_Loss:  0.181 | Accuracy:  0.862
# 0
# Test_Loss:  0.181 | Accuracy:  0.862
# 0
# Test_Loss:  0.181 | Accuracy:  0.863
# 0
# Test_Loss:  0.181 | Accuracy:  0.863
# 0
# Test_Loss:  0.181 | Accuracy:  0.863
# 0
# Test_Loss:  0.181 | Accuracy:  0.863
# 0
# Test_Loss:  0.181 | Accuracy:  0.863
# 0
# Test_Loss:  0.181 | Accuracy:  0.864
# 0
# Test_Loss:  0.181 | Accuracy:  0.864
# 0
# Test_Loss:  0.181 | Accuracy:  0.864
# 0
# Test_Loss:  0.181 | Accuracy:  0.864
# 0
# Test_Loss:  0.181 | Accuracy:  0.864
# 0
# Test_Loss:  0.181 | Accuracy:  0.865
# 0
# Test_Loss:  0.181 | Accuracy:  0.865
# 0
# Test_Loss:  0.181 | Accuracy:  0.865
# 0
# Test_Loss:  0.181 | Accuracy:  0.865
# 0
# Test_Loss:  0.182 | Accuracy:  0.865
# 0
# Test_Loss:  0.182 | Accuracy:  0.866
# 0
# Test_Loss:  0.182 | Accuracy:  0.866
# 0
# Test_Loss:  0.182 | Accuracy:  0.866
# 0
# Test_Loss:  0.182 | Accuracy:  0.866
# 0
# Test_Loss:  0.182 | Accuracy:  0.866
# 0
# Test_Loss:  0.182 | Accuracy:  0.867
# 0
# Test_Loss:  0.182 | Accuracy:  0.867
# 0
# Test_Loss:  0.182 | Accuracy:  0.867
# 0
# Test_Loss:  0.182 | Accuracy:  0.867
# 0
# Test_Loss:  0.182 | Accuracy:  0.867
# 0
# Test_Loss:  0.182 | Accuracy:  0.868
# 0
# Test_Loss:  0.182 | Accuracy:  0.868
# 0
# Test_Loss:  0.182 | Accuracy:  0.868
# 0
# Test_Loss:  0.182 | Accuracy:  0.868
# 0
# Test_Loss:  0.182 | Accuracy:  0.868
# 0
# Test_Loss:  0.182 | Accuracy:  0.869
# 0
# Test_Loss:  0.182 | Accuracy:  0.869
# 0
# Test_Loss:  0.182 | Accuracy:  0.869
# 0
# Test_Loss:  0.182 | Accuracy:  0.869
# 0
# Test_Loss:  0.182 | Accuracy:  0.869
# 0
# Test_Loss:  0.182 | Accuracy:  0.870
# 0
# Test_Loss:  0.182 | Accuracy:  0.870
# 0
# Test_Loss:  0.182 | Accuracy:  0.870
# 0
# Test_Loss:  0.182 | Accuracy:  0.870
# 0
# Test_Loss:  0.182 | Accuracy:  0.870
# 0
# Test_Loss:  0.182 | Accuracy:  0.871
# 0
# Test_Loss:  0.182 | Accuracy:  0.871
# 0
# Test_Loss:  0.182 | Accuracy:  0.871
# 0
# Test_Loss:  0.182 | Accuracy:  0.871
# 0
# Test_Loss:  0.182 | Accuracy:  0.871
# 0
# Test_Loss:  0.182 | Accuracy:  0.872
# 0
# Test_Loss:  0.182 | Accuracy:  0.872
# 0
# Test_Loss:  0.183 | Accuracy:  0.872
# 0
# Test_Loss:  0.183 | Accuracy:  0.872
# 0
# Test_Loss:  0.183 | Accuracy:  0.872
# 0
# Test_Loss:  0.183 | Accuracy:  0.873
# 0
# Test_Loss:  0.183 | Accuracy:  0.873
# 0
# Test_Loss:  0.183 | Accuracy:  0.873
# 0
# Test_Loss:  0.183 | Accuracy:  0.873
# 0
# Test_Loss:  0.183 | Accuracy:  0.873
# 0
# Test_Loss:  0.183 | Accuracy:  0.874
# 0
# Test_Loss:  0.183 | Accuracy:  0.874
# 0
# Test_Loss:  0.183 | Accuracy:  0.874
# 0
# Test_Loss:  0.183 | Accuracy:  0.874
# 0
# Test_Loss:  0.183 | Accuracy:  0.874
# 0
# Test_Loss:  0.183 | Accuracy:  0.875
# 0
# Test_Loss:  0.183 | Accuracy:  0.875
# 0
# Test_Loss:  0.183 | Accuracy:  0.875
# 0
# Test_Loss:  0.183 | Accuracy:  0.875
# 0
# Test_Loss:  0.183 | Accuracy:  0.875
# 0
# Test_Loss:  0.183 | Accuracy:  0.876
# 0
# Test_Loss:  0.183 | Accuracy:  0.876
# 0
# Test_Loss:  0.183 | Accuracy:  0.876
# 0
# Test_Loss:  0.183 | Accuracy:  0.876
# 0
# Test_Loss:  0.183 | Accuracy:  0.876
# 0
# Test_Loss:  0.183 | Accuracy:  0.877
# 0
# Test_Loss:  0.183 | Accuracy:  0.877
# 0
# Test_Loss:  0.183 | Accuracy:  0.877
# 0
# Test_Loss:  0.183 | Accuracy:  0.877
# 0
# Test_Loss:  0.183 | Accuracy:  0.877
# 0
# Test_Loss:  0.183 | Accuracy:  0.878
# 0
# Test_Loss:  0.184 | Accuracy:  0.878
# 0
# Test_Loss:  0.184 | Accuracy:  0.878
# 0
# Test_Loss:  0.184 | Accuracy:  0.878
# 0
# Test_Loss:  0.184 | Accuracy:  0.878
# 0
# Test_Loss:  0.184 | Accuracy:  0.878
# 0
# Test_Loss:  0.184 | Accuracy:  0.879
# 0
# Test_Loss:  0.184 | Accuracy:  0.879
# 0
# Test_Loss:  0.184 | Accuracy:  0.879
# 0
# Test_Loss:  0.184 | Accuracy:  0.879
# 0
# Test_Loss:  0.184 | Accuracy:  0.879
# 0
# Test_Loss:  0.184 | Accuracy:  0.880
# 0
# Test_Loss:  0.184 | Accuracy:  0.880
# 0
# Test_Loss:  0.184 | Accuracy:  0.880
# 0
# Test_Loss:  0.184 | Accuracy:  0.880
# 0
# Test_Loss:  0.184 | Accuracy:  0.880
# 0
# Test_Loss:  0.184 | Accuracy:  0.881
# 0
# Test_Loss:  0.184 | Accuracy:  0.881
# 0
# Test_Loss:  0.184 | Accuracy:  0.881
# 0
# Test_Loss:  0.184 | Accuracy:  0.881
# 0
# Test_Loss:  0.184 | Accuracy:  0.881
# 0
# Test_Loss:  0.184 | Accuracy:  0.882
# 0
# Test_Loss:  0.184 | Accuracy:  0.882
# 0
# Test_Loss:  0.184 | Accuracy:  0.882
# 0
# Test_Loss:  0.184 | Accuracy:  0.882
# 0
# Test_Loss:  0.184 | Accuracy:  0.882
# 0
# Test_Loss:  0.184 | Accuracy:  0.883
# 0
# Test_Loss:  0.184 | Accuracy:  0.883
# 0
# Test_Loss:  0.184 | Accuracy:  0.883
# 0
# Test_Loss:  0.184 | Accuracy:  0.883
# 0
# Test_Loss:  0.185 | Accuracy:  0.883
# 0
# Test_Loss:  0.185 | Accuracy:  0.884
# 0
# Test_Loss:  0.185 | Accuracy:  0.884
# 0
# Test_Loss:  0.185 | Accuracy:  0.884
# 0
# Test_Loss:  0.185 | Accuracy:  0.884
# 0
# Test_Loss:  0.185 | Accuracy:  0.884
# 0
# Test_Loss:  0.185 | Accuracy:  0.885
# 0
# Test_Loss:  0.185 | Accuracy:  0.885
# 0
# Test_Loss:  0.185 | Accuracy:  0.885
# 0
# Test_Loss:  0.185 | Accuracy:  0.885
# 0
# Test_Loss:  0.185 | Accuracy:  0.885
# 0
# Test_Loss:  0.185 | Accuracy:  0.886
# 0
# Test_Loss:  0.185 | Accuracy:  0.886
# 0
# Test_Loss:  0.185 | Accuracy:  0.886
# 0
# Test_Loss:  0.186 | Accuracy:  0.886
# 0
# Test_Loss:  0.186 | Accuracy:  0.886
# 0
# Test_Loss:  0.186 | Accuracy:  0.886
# 0
# Test_Loss:  0.186 | Accuracy:  0.887
# 0
# Test_Loss:  0.186 | Accuracy:  0.887
# 0
# Test_Loss:  0.186 | Accuracy:  0.887
# 0
# Test_Loss:  0.186 | Accuracy:  0.887
# 0
# Test_Loss:  0.186 | Accuracy:  0.888
# 0
# Test_Loss:  0.186 | Accuracy:  0.888
# 0
# Test_Loss:  0.186 | Accuracy:  0.888
# 0
# Test_Loss:  0.186 | Accuracy:  0.888
# 0
# Test_Loss:  0.186 | Accuracy:  0.888
# 0
# Test_Loss:  0.186 | Accuracy:  0.888
# 0
# Test_Loss:  0.186 | Accuracy:  0.889
# 0
# Test_Loss:  0.186 | Accuracy:  0.889
# 0
# Test_Loss:  0.186 | Accuracy:  0.889
# 0
# Test_Loss:  0.186 | Accuracy:  0.889
# 0
# Test_Loss:  0.186 | Accuracy:  0.890
# 0
# Test_Loss:  0.186 | Accuracy:  0.890
# 0
# Test_Loss:  0.186 | Accuracy:  0.890
# 0
# Test_Loss:  0.186 | Accuracy:  0.890
# 0
# Test_Loss:  0.186 | Accuracy:  0.890
# 0
# Test_Loss:  0.186 | Accuracy:  0.890
# 0
# Test_Loss:  0.186 | Accuracy:  0.891
# 0
# Test_Loss:  0.186 | Accuracy:  0.891
# 0
# Test_Loss:  0.186 | Accuracy:  0.891
# 0
# Test_Loss:  0.186 | Accuracy:  0.891
# 0
# Test_Loss:  0.186 | Accuracy:  0.891
# 0
# Test_Loss:  0.187 | Accuracy:  0.892
# 0
# Test_Loss:  0.187 | Accuracy:  0.892
# 0
# Test_Loss:  0.187 | Accuracy:  0.892
# 0
# Test_Loss:  0.187 | Accuracy:  0.892
# 0
# Test_Loss:  0.187 | Accuracy:  0.892
# 0
# Test_Loss:  0.187 | Accuracy:  0.893
# 0
# Test_Loss:  0.187 | Accuracy:  0.893
# 0
# Test_Loss:  0.187 | Accuracy:  0.893
# 0
# Test_Loss:  0.187 | Accuracy:  0.893
# 0
# Test_Loss:  0.187 | Accuracy:  0.893
# 0
# Test_Loss:  0.187 | Accuracy:  0.894
# 0
# Test_Loss:  0.187 | Accuracy:  0.894
# 0
# Test_Loss:  0.187 | Accuracy:  0.894
# 0
# Test_Loss:  0.187 | Accuracy:  0.894
# 0
# Test_Loss:  0.187 | Accuracy:  0.894
# 0
# Test_Loss:  0.187 | Accuracy:  0.895
# 0
# Test_Loss:  0.187 | Accuracy:  0.895
# 0
# Test_Loss:  0.187 | Accuracy:  0.895
# 0
# Test_Loss:  0.187 | Accuracy:  0.895
# 0
# Test_Loss:  0.187 | Accuracy:  0.895
# 0
# Test_Loss:  0.187 | Accuracy:  0.896
# 0
# Test_Loss:  0.187 | Accuracy:  0.896
# 0
# Test_Loss:  0.187 | Accuracy:  0.896
# 0
# Test_Loss:  0.187 | Accuracy:  0.896
# 0
# Test_Loss:  0.187 | Accuracy:  0.896
# 0
# Test_Loss:  0.187 | Accuracy:  0.897
# 0
# Test_Loss:  0.187 | Accuracy:  0.897
# 0
# Test_Loss:  0.187 | Accuracy:  0.897
# 0
# Test_Loss:  0.187 | Accuracy:  0.897
# 0
# Test_Loss:  0.187 | Accuracy:  0.897
# 0
# Test_Loss:  0.187 | Accuracy:  0.898
# 0
# Test_Loss:  0.187 | Accuracy:  0.898
# 0
# Test_Loss:  0.187 | Accuracy:  0.898
# 0
# Test_Loss:  0.187 | Accuracy:  0.898
# 0
# Test_Loss:  0.187 | Accuracy:  0.898
# 0
# Test_Loss:  0.187 | Accuracy:  0.899
# 0
# Test_Loss:  0.187 | Accuracy:  0.899
# 0
# Test_Loss:  0.187 | Accuracy:  0.899
# 0
# Test_Loss:  0.187 | Accuracy:  0.899
# 0
# Test_Loss:  0.187 | Accuracy:  0.899
# 0
# Test_Loss:  0.187 | Accuracy:  0.900
# 0
# Test_Loss:  0.187 | Accuracy:  0.900
# 0
# Test_Loss:  0.187 | Accuracy:  0.900
# 0
# Test_Loss:  0.187 | Accuracy:  0.900
# 0
# Test_Loss:  0.187 | Accuracy:  0.901
# 0
# Test_Loss:  0.187 | Accuracy:  0.901
# 0
# Test_Loss:  0.188 | Accuracy:  0.901
# 0
# Test_Loss:  0.188 | Accuracy:  0.901
# 0
# Test_Loss:  0.188 | Accuracy:  0.901
# 0
# Test_Loss:  0.188 | Accuracy:  0.902
# 0
# Test_Loss:  0.188 | Accuracy:  0.902
# 0
# Test_Loss:  0.188 | Accuracy:  0.902
# 0
# Test_Loss:  0.188 | Accuracy:  0.902
# 0
# Test_Loss:  0.188 | Accuracy:  0.902
# 0
# Test_Loss:  0.188 | Accuracy:  0.902
# 0
# Test_Loss:  0.188 | Accuracy:  0.903
# 0
# Test_Loss:  0.188 | Accuracy:  0.903
# 0
# Test_Loss:  0.188 | Accuracy:  0.903
# 0
# Test_Loss:  0.188 | Accuracy:  0.903
# 0
# Test_Loss:  0.188 | Accuracy:  0.903
# 0
# Test_Loss:  0.188 | Accuracy:  0.904
# 0
# Test_Loss:  0.188 | Accuracy:  0.904
# 0
# Test_Loss:  0.188 | Accuracy:  0.904
# 0
# Test_Loss:  0.188 | Accuracy:  0.904
# 0
# Test_Loss:  0.188 | Accuracy:  0.904
# 0
# Test_Loss:  0.188 | Accuracy:  0.905
# 0
# Test_Loss:  0.189 | Accuracy:  0.905
# 0
# Test_Loss:  0.189 | Accuracy:  0.905
# 0
# Test_Loss:  0.189 | Accuracy:  0.905
# 0
# Test_Loss:  0.189 | Accuracy:  0.905
# 0
# Test_Loss:  0.189 | Accuracy:  0.906
# 0
# Test_Loss:  0.189 | Accuracy:  0.906
# 0
# Test_Loss:  0.189 | Accuracy:  0.906
# 0
# Test_Loss:  0.189 | Accuracy:  0.906
# 0
# Test_Loss:  0.189 | Accuracy:  0.906
# 0
# Test_Loss:  0.189 | Accuracy:  0.907
# 0
# Test_Loss:  0.189 | Accuracy:  0.907
# 0
# Test_Loss:  0.189 | Accuracy:  0.907
# 0
# Test_Loss:  0.189 | Accuracy:  0.907
# 0
# Test_Loss:  0.189 | Accuracy:  0.907
# 0
# Test_Loss:  0.189 | Accuracy:  0.908
# 0
# Test_Loss:  0.189 | Accuracy:  0.908
# 0
# Test_Loss:  0.189 | Accuracy:  0.908
# 0
# Test_Loss:  0.189 | Accuracy:  0.908
# 0
# Test_Loss:  0.189 | Accuracy:  0.908
# 0
# Test_Loss:  0.189 | Accuracy:  0.909
# 0
# Test_Loss:  0.189 | Accuracy:  0.909
# 0
# Test_Loss:  0.189 | Accuracy:  0.909
# 0
# Test_Loss:  0.189 | Accuracy:  0.909
# 0
# Test_Loss:  0.189 | Accuracy:  0.909
# 0
# Test_Loss:  0.189 | Accuracy:  0.910
# 0
# Test_Loss:  0.189 | Accuracy:  0.910
# 0
# Test_Loss:  0.189 | Accuracy:  0.910
# 0
# Test_Loss:  0.190 | Accuracy:  0.910
# 0
# Test_Loss:  0.190 | Accuracy:  0.910
# 0
# Test_Loss:  0.190 | Accuracy:  0.911
# 0
# Test_Loss:  0.190 | Accuracy:  0.911
# 0
# Test_Loss:  0.190 | Accuracy:  0.911
# 0
# Test_Loss:  0.190 | Accuracy:  0.911
# 0
# Test_Loss:  0.190 | Accuracy:  0.911
# 0
# Test_Loss:  0.190 | Accuracy:  0.911
# 0
# Test_Loss:  0.190 | Accuracy:  0.912
# 0
# Test_Loss:  0.190 | Accuracy:  0.912
# 0
# Test_Loss:  0.190 | Accuracy:  0.912
# 0
# Test_Loss:  0.190 | Accuracy:  0.912
# 0
# Test_Loss:  0.190 | Accuracy:  0.912
# 0
# Test_Loss:  0.190 | Accuracy:  0.913
# 0
# Test_Loss:  0.190 | Accuracy:  0.913
# 0
# Test_Loss:  0.190 | Accuracy:  0.913
# 0
# Test_Loss:  0.190 | Accuracy:  0.913
# 0
# Test_Loss:  0.190 | Accuracy:  0.913
# 0
# Test_Loss:  0.190 | Accuracy:  0.914
# 0
# Test_Loss:  0.190 | Accuracy:  0.914
# 0
# Test_Loss:  0.190 | Accuracy:  0.914
# 0
# Test_Loss:  0.190 | Accuracy:  0.914
# 0
# Test_Loss:  0.190 | Accuracy:  0.914
# 0
# Test_Loss:  0.190 | Accuracy:  0.915
# 0
# Test_Loss:  0.190 | Accuracy:  0.915
# 0
# Test_Loss:  0.190 | Accuracy:  0.915
# 0
# Test_Loss:  0.190 | Accuracy:  0.915
# 0
# Test_Loss:  0.190 | Accuracy:  0.915
# 0
# Test_Loss:  0.190 | Accuracy:  0.916
# 0
# Test_Loss:  0.190 | Accuracy:  0.916
# 0
# Test_Loss:  0.191 | Accuracy:  0.916
# 0
# Test_Loss:  0.191 | Accuracy:  0.916
# 0
# Test_Loss:  0.191 | Accuracy:  0.916
# 0
# Test_Loss:  0.191 | Accuracy:  0.917
# 0
# Test_Loss:  0.191 | Accuracy:  0.917
# 0
# Test_Loss:  0.191 | Accuracy:  0.917
# 0
# Test_Loss:  0.191 | Accuracy:  0.917
# 0
# Test_Loss:  0.191 | Accuracy:  0.917
# 0
# Test_Loss:  0.191 | Accuracy:  0.918
# 0
# Test_Loss:  0.191 | Accuracy:  0.918
# 0
# Test_Loss:  0.191 | Accuracy:  0.918
# 0
# Test_Loss:  0.191 | Accuracy:  0.918
# 0
# Test_Loss:  0.191 | Accuracy:  0.918
# 0
# Test_Loss:  0.191 | Accuracy:  0.919
# 0
# Test_Loss:  0.191 | Accuracy:  0.919
# 0
# Test_Loss:  0.191 | Accuracy:  0.919
# 0
# Test_Loss:  0.191 | Accuracy:  0.919
# 0
# Test_Loss:  0.191 | Accuracy:  0.919
# 0
# Test_Loss:  0.191 | Accuracy:  0.920
# 0
# Test_Loss:  0.191 | Accuracy:  0.920
# 0
# Test_Loss:  0.191 | Accuracy:  0.920
# 0
# Test_Loss:  0.192 | Accuracy:  0.920
# 0
# Test_Loss:  0.192 | Accuracy:  0.920
# 0
# Test_Loss:  0.192 | Accuracy:  0.920
# 0
# Test_Loss:  0.192 | Accuracy:  0.921
# 0
# Test_Loss:  0.192 | Accuracy:  0.921
# 0
# Test_Loss:  0.192 | Accuracy:  0.921
# 0
# Test_Loss:  0.192 | Accuracy:  0.921
# 0
# Test_Loss:  0.192 | Accuracy:  0.921
# 0
# Test_Loss:  0.192 | Accuracy:  0.922
# 0
# Test_Loss:  0.192 | Accuracy:  0.922
# 0
# Test_Loss:  0.192 | Accuracy:  0.922
# 0
# Test_Loss:  0.192 | Accuracy:  0.922
# 0
# Test_Loss:  0.192 | Accuracy:  0.922
# 0
# Test_Loss:  0.192 | Accuracy:  0.923
# 0
# Test_Loss:  0.192 | Accuracy:  0.923
# 0
# Test_Loss:  0.192 | Accuracy:  0.923
# 0
# Test_Loss:  0.192 | Accuracy:  0.923
# 0
# Test_Loss:  0.192 | Accuracy:  0.923
# 0
# Test_Loss:  0.193 | Accuracy:  0.924
# 0
# Test_Loss:  0.193 | Accuracy:  0.924
# 0
# Test_Loss:  0.193 | Accuracy:  0.924
# 0
# Test_Loss:  0.193 | Accuracy:  0.924
# 0
# Test_Loss:  0.193 | Accuracy:  0.924
# 0
# Test_Loss:  0.193 | Accuracy:  0.925
# 0
# Test_Loss:  0.193 | Accuracy:  0.925
# 0
# Test_Loss:  0.193 | Accuracy:  0.925
# 0
# Test_Loss:  0.193 | Accuracy:  0.925
# 0
# Test_Loss:  0.193 | Accuracy:  0.925
# 0
# Test_Loss:  0.193 | Accuracy:  0.926
# 0
# Test_Loss:  0.193 | Accuracy:  0.926
# 0
# Test_Loss:  0.193 | Accuracy:  0.926
# 0
# Test_Loss:  0.193 | Accuracy:  0.926
# 0
# Test_Loss:  0.193 | Accuracy:  0.926
# 0
# Test_Loss:  0.193 | Accuracy:  0.927
# 0
# Test_Loss:  0.193 | Accuracy:  0.927
# 0
# Test_Loss:  0.193 | Accuracy:  0.927
# 0
# Test_Loss:  0.193 | Accuracy:  0.927
# 0
# Test_Loss:  0.193 | Accuracy:  0.927
# 0
# Test_Loss:  0.193 | Accuracy:  0.928
# 0
# Test_Loss:  0.193 | Accuracy:  0.928
# 0
# Test_Loss:  0.193 | Accuracy:  0.928
# 0
# Test_Loss:  0.193 | Accuracy:  0.928
# 0
# Test_Loss:  0.193 | Accuracy:  0.928
# 0
# Test_Loss:  0.193 | Accuracy:  0.929
# 0
# Test_Loss:  0.193 | Accuracy:  0.929
# 0
# Test_Loss:  0.193 | Accuracy:  0.929
# 0
# Test_Loss:  0.193 | Accuracy:  0.929
# 0
# Test_Loss:  0.193 | Accuracy:  0.929
# 0
# Test_Loss:  0.193 | Accuracy:  0.930
# 0
# Test_Loss:  0.193 | Accuracy:  0.930
# 0
# Test_Loss:  0.194 | Accuracy:  0.930
# 0
# Test_Loss:  0.194 | Accuracy:  0.930
# 0
# Test_Loss:  0.194 | Accuracy:  0.930
# 0
# Test_Loss:  0.194 | Accuracy:  0.930
# 0
# Test_Loss:  0.194 | Accuracy:  0.931
# 0
# Test_Loss:  0.194 | Accuracy:  0.931
# 0
# Test_Loss:  0.194 | Accuracy:  0.931
# 0
# Test_Loss:  0.194 | Accuracy:  0.931
# 0
# Test_Loss:  0.194 | Accuracy:  0.931
# 0
# Test_Loss:  0.194 | Accuracy:  0.932
# 0
# Test_Loss:  0.194 | Accuracy:  0.932
# 0
# Test_Loss:  0.194 | Accuracy:  0.932
# 0
# Test_Loss:  0.194 | Accuracy:  0.932
# 0
# Test_Loss:  0.194 | Accuracy:  0.933
# 0
# Test_Loss:  0.194 | Accuracy:  0.933
# 0
# Test_Loss:  0.194 | Accuracy:  0.933
# 0
# Test_Loss:  0.194 | Accuracy:  0.933
# 0
# Test_Loss:  0.194 | Accuracy:  0.933
# 0
# Test_Loss:  0.194 | Accuracy:  0.933
# 0
# Test_Loss:  0.194 | Accuracy:  0.934
# 0
# Test_Loss:  0.194 | Accuracy:  0.934
# 0
# Test_Loss:  0.194 | Accuracy:  0.934
# 0
# Test_Loss:  0.194 | Accuracy:  0.934
# 0
# Test_Loss:  0.194 | Accuracy:  0.934
# 0
# Test_Loss:  0.195 | Accuracy:  0.935
# 0
# Test_Loss:  0.195 | Accuracy:  0.935
# 0
# Test_Loss:  0.195 | Accuracy:  0.935
# 0
# Test_Loss:  0.195 | Accuracy:  0.935
# 0
# Test_Loss:  0.195 | Accuracy:  0.935
# 0
# Test_Loss:  0.195 | Accuracy:  0.936
# 0
# Test_Loss:  0.195 | Accuracy:  0.936
# 0
# Test_Loss:  0.195 | Accuracy:  0.936
# 0
# Test_Loss:  0.195 | Accuracy:  0.936
# 0
# Test_Loss:  0.195 | Accuracy:  0.936
# 0
# Test_Loss:  0.195 | Accuracy:  0.937
# 0
# Test_Loss:  0.195 | Accuracy:  0.937
# 0
# Test_Loss:  0.195 | Accuracy:  0.937
# 0
# Test_Loss:  0.195 | Accuracy:  0.937
# 0
# Test_Loss:  0.195 | Accuracy:  0.938
# 0
# Test_Loss:  0.195 | Accuracy:  0.938
# 0
# Test_Loss:  0.195 | Accuracy:  0.938
